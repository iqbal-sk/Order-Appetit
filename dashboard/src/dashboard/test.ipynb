# %%
from pymongo.mongo_client import MongoClient
import os
from dotenv import load_dotenv

load_dotenv()

uri = os.getenv("mongodb_uri")
# Create a new client and connect to the server
client = MongoClient(uri)

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:

    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# Choose 'appetit_db' database
db = client['appetit_db']

# List collections in 'appetit_db'
collections = db.list_collection_names()
print(f"Collections in appetit_db:", collections)
# Out:
# Collections in appetit_db: ['agenda_schedule', 'agenda_schedules', 'asap_schedules', 'categories', 'chowlydetails', 'customer_logs', 'delivery_fees', 'delivery_reservation_availabilities', 'delivery_settlements', 'dine_reservation_availabilities', 'locations', 'merchant_logs', 'merchant_settings', 'orders', 'pickup_reservation_availabilities', 'product_categories', 'product_common_modifiers', 'products', 'promo_codes', 'promos', 'refreshtokens', 'search_filters', 'settlements', 'shipday_logs', 'store_delivery_time_slots', 'store_dinein_time_slots', 'store_pickup_time_slots', 'store_schedules', 'store_tables', 'stores', 'tags', 'users', 'versions', 'voucher_codes', 'vouchers']

# %%
import datetime
from typing import Dict, List, Any
from decimal import Decimal, InvalidOperation

def safe_decimal_convert(value) -> Decimal:
    """
    Safely convert a value to Decimal, handling None and invalid values
    """
    if value is None:
        return Decimal('0')
    try:
        if isinstance(value, (int, float)):
            return Decimal(str(value))
        return Decimal(str(value))
    except (InvalidOperation, TypeError, ValueError):
        return Decimal('0')

def safe_division(numerator: Decimal, denominator: Decimal) -> Decimal:
    """
    Safely perform division, handling division by zero
    """
    try:
        if denominator == 0:
            return Decimal('0')
        return numerator / denominator
    except (InvalidOperation, TypeError, ValueError):
        return Decimal('0')

def get_least_performing_restaurants(db) -> Dict[str, Any]:
    """
    Fetches least performing restaurants based on order volume,
    including both volume and value metrics
    """
    pipeline = [
        {
            "$match": {
                "createdAt": {
                    "$gte": datetime.datetime.now() - datetime.timedelta(days=180),
                    "$lt": datetime.datetime.now()
                }
            }
        },
        {
            "$group": {
                "_id": "$store_id",
                "total_orders": {"$sum": 1},
                "total_value": {"$sum": "$orderValue"},
                "average_order_value": {"$avg": "$orderValue"},
                "monthly_stats": {
                    "$push": {
                        "month": {"$month": "$createdAt"},
                        "year": {"$year": "$createdAt"},
                        "value": "$orderValue"
                    }
                }
            }
        },
        {
            "$lookup": {
                "from": "stores",
                "localField": "_id",
                "foreignField": "_id",
                "as": "store_details"
            }
        },
        {
            "$unwind": "$store_details"
        },
        {
            "$project": {
                "store_name": "$store_details.name",
                "total_orders": 1,
                "total_value": 1,
                "average_order_value": 1,
                "monthly_stats": 1
            }
        },
        {
            "$sort": {"total_orders": 1}
        },
        {
            "$limit": 10
        }
    ]

    results = list(db.orders.aggregate(pipeline))
    
    def process_monthly_stats(stats):
        monthly_dict = {}
        for stat in stats:
            month_key = f"{stat.get('year', 0)}-{stat.get('month', 0):02d}"
            if month_key not in monthly_dict:
                monthly_dict[month_key] = {
                    "orders": 0,
                    "value": Decimal('0')
                }
            monthly_dict[month_key]["orders"] += 1
            monthly_dict[month_key]["value"] += safe_decimal_convert(stat.get('value', 0))
        
        return [
            {
                "month": k,
                "orders": v["orders"],
                "value": float(round(v["value"], 2))
            }
            for k, v in sorted(monthly_dict.items())
        ]

    # Calculate overall metrics with safe conversion
    total_system_volume = Decimal(sum(r.get("total_orders", 0) for r in results))
    total_system_value = sum(safe_decimal_convert(r.get("total_value", 0)) for r in results)
    
    return {
        "restaurant_breakdown": [
            {
                "store_name": r.get("store_name", "Unknown"),
                "metrics": {
                    "total_orders": r.get("total_orders", 0),
                    "total_value": float(round(safe_decimal_convert(r.get("total_value", 0)), 2)),
                    "average_order_value": float(round(safe_decimal_convert(r.get("average_order_value", 0)), 2)),
                    "volume_percentage": float(round(safe_division(
                        safe_decimal_convert(r.get("total_orders", 0)) * Decimal('100'),
                        total_system_volume
                    ), 2)),
                    "value_percentage": float(round(safe_division(
                        safe_decimal_convert(r.get("total_value", 0)) * Decimal('100'),
                        total_system_value
                    ), 2))
                },
                "monthly_performance": process_monthly_stats(r.get("monthly_stats", []))
            }
            for r in results
        ],
        "aggregated_metrics": {
            "total_volume": int(total_system_volume),
            "total_value": float(round(total_system_value, 2)),
            "average_order_value": float(round(
                safe_division(total_system_value, total_system_volume), 
                2
            )),
            "analysis_period": {
                "start_date": (datetime.datetime.now() - datetime.timedelta(days=180)).strftime("%Y-%m-%d"),
                "end_date": datetime.datetime.now().strftime("%Y-%m-%d")
            },
            "restaurants_analyzed": len(results)
        },
        "performance_indicators": {
            "volume_threshold": float(round(
                safe_division(total_system_volume, Decimal(str(len(results) if results else 1))),
                2
            )),
            "value_threshold": float(round(
                safe_division(total_system_value, Decimal(str(len(results) if results else 1))),
                2
            ))
        }
    }

# %%
get_least_performing_restaurants(db)
# Out:
# {'restaurant_breakdown': [{'store_name': "Hanzlian's Homemade Sausage",
#    'metrics': {'total_orders': 2,
#     'total_value': 0.0,
#     'average_order_value': 0.0,
#     'volume_percentage': 4.55,
#     'value_percentage': 0.0},
#    'monthly_performance': [{'month': '2024-10', 'orders': 1, 'value': 0.0},
#     {'month': '2024-11', 'orders': 1, 'value': 0.0}]},
#   {'store_name': 'Two Nines Kitchen & Bar',
#    'metrics': {'total_orders': 2,
#     'total_value': 0.0,
#     'average_order_value': 0.0,
#     'volume_percentage': 4.55,
#     'value_percentage': 0.0},
#    'monthly_performance': [{'month': '2024-09', 'orders': 2, 'value': 0.0}]},
#   {'store_name': 'Oralia',
#    'metrics': {'total_orders': 3,
#     'total_value': 0.0,
#     'average_order_value': 0.0,
#     'volume_percentage': 6.82,
#     'value_percentage': 0.0},
#    'monthly_performance': [{'month': '2024-07', 'orders': 3, 'value': 0.0}]},
#   {'store_name': 'La Verdad',
#    'metrics': {'total_orders': 4,
#     'total_value': 0.0,
#     'average_order_value': 0.0,
#     'volume_percentage': 9.09,
#     'value_percentage': 0.0},
#    'monthly_performance': [{'month': '2024-05', 'orders': 1, 'value': 0.0},
#     {'month': '2024-07', 'orders': 1, 'value': 0.0},
#     {'month': '2024-10', 'orders': 1, 'value': 0.0},
#     {'month': '2024-11', 'orders': 1, 'value': 0.0}]},
#   {'store_name': "VinLouie's",
#    'metrics': {'total_orders': 4,
#     'total_value': 0.0,
#     'average_order_value': 0.0,
#     'volume_percentage': 9.09,
#     'value_percentage': 0.0},
#    'monthly_performance': [{'month': '2024-05', 'orders': 1, 'value': 0.0},
#     {'month': '2024-06', 'orders': 1, 'value': 0.0},
#     {'month': '2024-08', 'orders': 2, 'value': 0.0}]},
#   {'store_name': 'Egyptian Bites',
#    'metrics': {'total_orders': 4,
#     'total_value': 0.0,
#     'average_order_value': 0.0,
#     'volume_percentage': 9.09,
#     'value_percentage': 0.0},
#    'monthly_performance': [{'month': '2024-10', 'orders': 2, 'value': 0.0},
#     {'month': '2024-11', 'orders': 2, 'value': 0.0}]},
#   {'store_name': 'Mister Pizza | Elmwood',
#    'metrics': {'total_orders': 5,
#     'total_value': 0.0,
#     'average_order_value': 0.0,
#     'volume_percentage': 11.36,
#     'value_percentage': 0.0},
#    'monthly_performance': [{'month': '2024-05', 'orders': 1, 'value': 0.0},
#     {'month': '2024-07', 'orders': 1, 'value': 0.0},
#     {'month': '2024-08', 'orders': 1, 'value': 0.0},
#     {'month': '2024-10', 'orders': 2, 'value': 0.0}]},
#   {'store_name': 'Hombre Y Lobo',
#    'metrics': {'total_orders': 5,
#     'total_value': 0.0,
#     'average_order_value': 0.0,
#     'volume_percentage': 11.36,
#     'value_percentage': 0.0},
#    'monthly_performance': [{'month': '2024-06', 'orders': 3, 'value': 0.0},
#     {'month': '2024-07', 'orders': 1, 'value': 0.0},
#     {'month': '2024-09', 'orders': 1, 'value': 0.0}]},
#   {'store_name': 'Old Orchard Inn',
#    'metrics': {'total_orders': 7,
#     'total_value': 0.0,
#     'average_order_value': 0.0,
#     'volume_percentage': 15.91,
#     'value_percentage': 0.0},
#    'monthly_performance': [{'month': '2024-06', 'orders': 1, 'value': 0.0},
#     {'month': '2024-07', 'orders': 4, 'value': 0.0},
#     {'month': '2024-08', 'orders': 1, 'value': 0.0},
#     {'month': '2024-11', 'orders': 1, 'value': 0.0}]},
#   {'store_name': 'India Gate',
#    'metrics': {'total_orders': 8,
#     'total_value': 0.0,
#     'average_order_value': 0.0,
#     'volume_percentage': 18.18,
#     'value_percentage': 0.0},
#    'monthly_performance': [{'month': '2024-05', 'orders': 2, 'value': 0.0},
#     {'month': '2024-06', 'orders': 3, 'value': 0.0},
#     {'month': '2024-07', 'orders': 2, 'value': 0.0},
#     {'month': '2024-11', 'orders': 1, 'value': 0.0}]}],
#  'aggregated_metrics': {'total_volume': 44,
#   'total_value': 0.0,
#   'average_order_value': 0.0,
#   'analysis_period': {'start_date': '2024-05-19', 'end_date': '2024-11-15'},
#   'restaurants_analyzed': 10},
#  'performance_indicators': {'volume_threshold': 4.4, 'value_threshold': 0.0}}

# %%
def get_average_order_value_by_user(db) -> Dict[str, Any]:
    """
    Fetches average order value by user with additional metrics
    """
    pipeline = [
        {
            "$group": {
                "_id": "$user_id",
                "average_order_value": {"$avg": "$total_amount"},
                "total_orders": {"$sum": 1},
                "total_spent": {"$sum": "$total_amount"}
            }
        },
        {
            "$lookup": {
                "from": "users",
                "localField": "_id",
                "foreignField": "_id",
                "as": "user_details"
            }
        },
        {
            "$unwind": "$user_details"
        },
        {
            "$project": {
                "user_name": "$user_details.name",
                "average_order_value": 1,
                "total_orders": 1,
                "total_spent": 1
            }
        },
        {
            "$sort": {"average_order_value": -1}
        }
    ]

    results = list(db.orders.aggregate(pipeline))
    
    print(results[0])
    
    return {
        "user_metrics": [
            {
                "user_name": r["_id"],
                "average_order_value": float(round(Decimal(str(r["average_order_value"])), 2)),
                "total_orders": r["total_orders"],
                "total_spent": float(round(Decimal(str(r["total_spent"])), 2))
            }
            for r in results
        ],
        "aggregated_metrics": {
            "overall_average_order_value": float(round(Decimal(str(
                sum(r["total_spent"] for r in results) / sum(r["total_orders"] for r in results)
            )), 2)),
            "total_users": len(results),
            "total_orders": sum(r["total_orders"] for r in results)
        }
    }

# %%
get_average_order_value_by_user(db)
# Out:
# {'_id': ObjectId('659d7b886225e63b82132f0f'), 'average_order_value': 650.9, 'total_orders': 1, 'total_spent': 650.9}
# ---------------------------------------------------------------------------
# InvalidOperation                          Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 get_average_order_value_by_user(db)
#
# Cell In[13], line 46, in get_average_order_value_by_user(db)
#      38 results = list(db.orders.aggregate(pipeline))
#      40 print(results[0])
#      42 return {
#      43     "user_metrics": [
#      44         {
#      45             "user_name": r["_id"],
# ---> 46             "average_order_value": float(round(Decimal(str(r["average_order_value"])), 2)),
#      47             "total_orders": r["total_orders"],
#      48             "total_spent": float(round(Decimal(str(r["total_spent"])), 2))
#      49         }
#      50         for r in results
#      51     ],
#      52     "aggregated_metrics": {
#      53         "overall_average_order_value": float(round(Decimal(str(
#      54             sum(r["total_spent"] for r in results) / sum(r["total_orders"] for r in results)
#      55         )), 2)),
#      56         "total_users": len(results),
#      57         "total_orders": sum(r["total_orders"] for r in results)
#      58     }
#      59 }
#
# InvalidOperation: [<class 'decimal.ConversionSyntax'>]

# %% [markdown]
# # Monthly orders for each restaurant in 2024

# %%
import datetime  # Add this import for datetime
import json


pipeline = [
    {
        "$match": {
            "createdAt": {"$gte": datetime.datetime(2024, 1, 1), "$lt": datetime.datetime(2025, 1, 1)}
        }
    },
    {
        "$group": {
            "_id": {
                "month": {"$month": "$createdAt"},
                "store_id": "$store_id"
            },
            "total_orders": {"$sum": 1}
        }
    },
    {
        "$lookup": {
            "from": "stores",  # adjust if your collection name differs
            "localField": "_id.store_id",
            "foreignField": "_id",
            "as": "store_details"
        }
    },
    {
        "$unwind": "$store_details"
    },
    {
        "$project": {
            "month": "$_id.month",
            "store_name": "$store_details.name",
            "total_orders": 1
        }
    },
    {
        "$sort": {"month": 1, "store_name": 1}
    }
]




results = db.orders.aggregate(pipeline)
results_list = list(results)  # Convert cursor to list

# Print results as JSON
print(json.dumps(results_list, indent=2, default=str))
# Out:
# [
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "5ffe033b5465ffa6c93cde70"
#     },
#     "total_orders": 28,
#     "month": 1,
#     "store_name": "Aguacates Mexican Bar & Grill | Elmwood"
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "5fb5bf5934d2dc3679565cac"
#     },
#     "total_orders": 21,
#     "month": 1,
#     "store_name": "Ballyhoo"
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "64fb74ecd347663f1e74be2c"
#     },
#     "total_orders": 55,
#     "month": 1,
#     "store_name": "Buffalo Deep Dish"
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "5fb57c6e34d2dc77f8565a76"
#     },
#     "total_orders": 12,
#     "month": 1,
#     "store_name": "Butera's Craft Beer & Craft Pizza"
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "5fc5707c0642fe105f7bf56d"
#     },
#     "total_orders": 47,
#     "month": 1,
#     "store_name": "Cafe 59"
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "5f9c37a75c9bb54266ffafc1"
#     },
#     "total_orders": 4,
#     "month": 1,
#     "store_name": "Colter Bay"
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "5fa18d605c9bb56497ffb1ee"
#     },
#     "total_orders": 22,
#     "month": 1,
#     "store_name": "Fat Bob's Smokehouse"
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "6384da2ef82eb777db9fd0f7"
#     },
#     "total_orders": 4,
#     "month": 1,
#     "store_name": "Giacobbi's Cucina Citta"
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "5fda363171684a8075618c44"
#     },
#     "total_orders": 24,
#     "month": 1,
#     "store_name": "Glen Park Tavern "
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "6422ecc5a7f10a43c4ff6baf"
#     },
#     "total_orders": 19,
#     "month": 1,
#     "store_name": "Grass Fed Vegan Butcher Shop"
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "61548c5d382e639bac6f3eb6"
#     },
#     "total_orders": 1,
#     "month": 1,
#     "store_name": "Hombre Y Lobo"
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "638f9b40f82eb70394a005f7"
#     },
#     "total_orders": 69,
#     "month": 1,
#     "store_name": "K Dara Noodle Bar"
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "6567471925523d16798c60ea"
#     },
#     "total_orders": 2,
#     "month": 1,
#     "store_name": "La Verdad"
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "60abca42c4354a1c628ca314"
#     },
#     "total_orders": 11,
#     "month": 1,
#     "store_name": "Lakeshore Cafe"
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "63208ee5a7d7d40f864cde37"
#     },
#     "total_orders": 12,
#     "month": 1,
#     "store_name": "Lime House Sushi & Ramen | Hamburg"
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "5ffdbf7e5465ff35ee3cd414"
#     },
#     "total_orders": 10,
#     "month": 1,
#     "store_name": "Louie's Texas Red Hots - Orchard Park "
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "5fcbb4e054c1706025d59aae"
#     },
#     "total_orders": 4,
#     "month": 1,
#     "store_name": "Marco\u2019s Italian Restaurant "
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "64b6c970e2bd6e48353ec919"
#     },
#     "total_orders": 6,
#     "month": 1,
#     "store_name": "Mario's Bistro & Brews"
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "6214f1ecb93c4f44247387a9"
#     },
#     "total_orders": 10,
#     "month": 1,
#     "store_name": "Milk & Tea"
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "5fca95755db8af8a2ca5c19b"
#     },
#     "total_orders": 24,
#     "month": 1,
#     "store_name": "Off The Wall Sandwich Company"
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "640623750de38a7b959b6a0a"
#     },
#     "total_orders": 2,
#     "month": 1,
#     "store_name": "Old Orchard Inn"
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "6544d1c8ebde7d15e2e7cf13"
#     },
#     "total_orders": 6,
#     "month": 1,
#     "store_name": "Pham's Kitchen"
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "602d2d8263b7e5c183f269be"
#     },
#     "total_orders": 8,
#     "month": 1,
#     "store_name": "Pizza Plant Transit"
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "62308c07e360923779cc8053"
#     },
#     "total_orders": 31,
#     "month": 1,
#     "store_name": "Rin Thai Bistro"
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "618027873904904abf8f9ff7"
#     },
#     "total_orders": 73,
#     "month": 1,
#     "store_name": "Sports City Pizza Pub"
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "6350035aaf0c66c48da29d93"
#     },
#     "total_orders": 15,
#     "month": 1,
#     "store_name": "The Grange Outpost"
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "5fbcffb9e59b5518a91a66fe"
#     },
#     "total_orders": 7,
#     "month": 1,
#     "store_name": "Undergrounds Coffee House and Roastery "
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "609033cb7bc821c6efe810d3"
#     },
#     "total_orders": 2,
#     "month": 1,
#     "store_name": "VinLouie's"
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "61b8dad221a96859e2c43133"
#     },
#     "total_orders": 23,
#     "month": 1,
#     "store_name": "Voula's Greek Sweets"
#   },
#   {
#     "_id": {
#       "month": 1,
#       "store_id": "63e143fc0de38a94a99a7559"
#     },
#     "total_orders": 2,
#     "month": 1,
#     "store_name": "Winfield's Pub"
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "5ffe033b5465ffa6c93cde70"
#     },
#     "total_orders": 34,
#     "month": 2,
#     "store_name": "Aguacates Mexican Bar & Grill | Elmwood"
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "5fa42c8d7cc0c3189e350a3b"
#     },
#     "total_orders": 3,
#     "month": 2,
#     "store_name": "Allentown Pizza"
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "5fb5bf5934d2dc3679565cac"
#     },
#     "total_orders": 24,
#     "month": 2,
#     "store_name": "Ballyhoo"
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "64fb74ecd347663f1e74be2c"
#     },
#     "total_orders": 54,
#     "month": 2,
#     "store_name": "Buffalo Deep Dish"
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "5fb57c6e34d2dc77f8565a76"
#     },
#     "total_orders": 10,
#     "month": 2,
#     "store_name": "Butera's Craft Beer & Craft Pizza"
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "5fc5707c0642fe105f7bf56d"
#     },
#     "total_orders": 56,
#     "month": 2,
#     "store_name": "Cafe 59"
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "5f9c37a75c9bb54266ffafc1"
#     },
#     "total_orders": 1,
#     "month": 2,
#     "store_name": "Colter Bay"
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "5fa18d605c9bb56497ffb1ee"
#     },
#     "total_orders": 41,
#     "month": 2,
#     "store_name": "Fat Bob's Smokehouse"
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "6384da2ef82eb777db9fd0f7"
#     },
#     "total_orders": 8,
#     "month": 2,
#     "store_name": "Giacobbi's Cucina Citta"
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "5fda363171684a8075618c44"
#     },
#     "total_orders": 17,
#     "month": 2,
#     "store_name": "Glen Park Tavern "
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "6422ecc5a7f10a43c4ff6baf"
#     },
#     "total_orders": 26,
#     "month": 2,
#     "store_name": "Grass Fed Vegan Butcher Shop"
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "61548c5d382e639bac6f3eb6"
#     },
#     "total_orders": 1,
#     "month": 2,
#     "store_name": "Hombre Y Lobo"
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "603aa3bda246a7772f08ce25"
#     },
#     "total_orders": 6,
#     "month": 2,
#     "store_name": "India Gate"
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "638f9b40f82eb70394a005f7"
#     },
#     "total_orders": 67,
#     "month": 2,
#     "store_name": "K Dara Noodle Bar"
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "6567471925523d16798c60ea"
#     },
#     "total_orders": 2,
#     "month": 2,
#     "store_name": "La Verdad"
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "60abca42c4354a1c628ca314"
#     },
#     "total_orders": 24,
#     "month": 2,
#     "store_name": "Lakeshore Cafe"
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "63208ee5a7d7d40f864cde37"
#     },
#     "total_orders": 8,
#     "month": 2,
#     "store_name": "Lime House Sushi & Ramen | Hamburg"
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "5ffdbf7e5465ff35ee3cd414"
#     },
#     "total_orders": 13,
#     "month": 2,
#     "store_name": "Louie's Texas Red Hots - Orchard Park "
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "5fcbb4e054c1706025d59aae"
#     },
#     "total_orders": 2,
#     "month": 2,
#     "store_name": "Marco\u2019s Italian Restaurant "
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "64b6c970e2bd6e48353ec919"
#     },
#     "total_orders": 6,
#     "month": 2,
#     "store_name": "Mario's Bistro & Brews"
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "6214f1ecb93c4f44247387a9"
#     },
#     "total_orders": 12,
#     "month": 2,
#     "store_name": "Milk & Tea"
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "5fca95755db8af8a2ca5c19b"
#     },
#     "total_orders": 25,
#     "month": 2,
#     "store_name": "Off The Wall Sandwich Company"
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "6544d1c8ebde7d15e2e7cf13"
#     },
#     "total_orders": 6,
#     "month": 2,
#     "store_name": "Pham's Kitchen"
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "602d2d8263b7e5c183f269be"
#     },
#     "total_orders": 17,
#     "month": 2,
#     "store_name": "Pizza Plant Transit"
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "62308c07e360923779cc8053"
#     },
#     "total_orders": 24,
#     "month": 2,
#     "store_name": "Rin Thai Bistro"
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "618027873904904abf8f9ff7"
#     },
#     "total_orders": 57,
#     "month": 2,
#     "store_name": "Sports City Pizza Pub"
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "6350035aaf0c66c48da29d93"
#     },
#     "total_orders": 14,
#     "month": 2,
#     "store_name": "The Grange Outpost"
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "6579ee1925523d220c9959ca"
#     },
#     "total_orders": 21,
#     "month": 2,
#     "store_name": "The Ridge West Seneca"
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "5fbcffb9e59b5518a91a66fe"
#     },
#     "total_orders": 5,
#     "month": 2,
#     "store_name": "Undergrounds Coffee House and Roastery "
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "609033cb7bc821c6efe810d3"
#     },
#     "total_orders": 2,
#     "month": 2,
#     "store_name": "VinLouie's"
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "61b8dad221a96859e2c43133"
#     },
#     "total_orders": 31,
#     "month": 2,
#     "store_name": "Voula's Greek Sweets"
#   },
#   {
#     "_id": {
#       "month": 2,
#       "store_id": "63e143fc0de38a94a99a7559"
#     },
#     "total_orders": 7,
#     "month": 2,
#     "store_name": "Winfield's Pub"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "5ffe033b5465ffa6c93cde70"
#     },
#     "total_orders": 37,
#     "month": 3,
#     "store_name": "Aguacates Mexican Bar & Grill | Elmwood"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "5fa42c8d7cc0c3189e350a3b"
#     },
#     "total_orders": 2,
#     "month": 3,
#     "store_name": "Allentown Pizza"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "5fb5bf5934d2dc3679565cac"
#     },
#     "total_orders": 19,
#     "month": 3,
#     "store_name": "Ballyhoo"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "64fb74ecd347663f1e74be2c"
#     },
#     "total_orders": 55,
#     "month": 3,
#     "store_name": "Buffalo Deep Dish"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "5fb57c6e34d2dc77f8565a76"
#     },
#     "total_orders": 15,
#     "month": 3,
#     "store_name": "Butera's Craft Beer & Craft Pizza"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "5fc5707c0642fe105f7bf56d"
#     },
#     "total_orders": 59,
#     "month": 3,
#     "store_name": "Cafe 59"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "5f9c37a75c9bb54266ffafc1"
#     },
#     "total_orders": 1,
#     "month": 3,
#     "store_name": "Colter Bay"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "5fa18d605c9bb56497ffb1ee"
#     },
#     "total_orders": 38,
#     "month": 3,
#     "store_name": "Fat Bob's Smokehouse"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "6384da2ef82eb777db9fd0f7"
#     },
#     "total_orders": 6,
#     "month": 3,
#     "store_name": "Giacobbi's Cucina Citta"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "5fda363171684a8075618c44"
#     },
#     "total_orders": 23,
#     "month": 3,
#     "store_name": "Glen Park Tavern "
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "6422ecc5a7f10a43c4ff6baf"
#     },
#     "total_orders": 24,
#     "month": 3,
#     "store_name": "Grass Fed Vegan Butcher Shop"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "63cfefbd415cbf4fcae7a83a"
#     },
#     "total_orders": 1,
#     "month": 3,
#     "store_name": "Hanzlian's Homemade Sausage"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "61548c5d382e639bac6f3eb6"
#     },
#     "total_orders": 1,
#     "month": 3,
#     "store_name": "Hombre Y Lobo"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "603aa3bda246a7772f08ce25"
#     },
#     "total_orders": 1,
#     "month": 3,
#     "store_name": "India Gate"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "638f9b40f82eb70394a005f7"
#     },
#     "total_orders": 89,
#     "month": 3,
#     "store_name": "K Dara Noodle Bar"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "6567471925523d16798c60ea"
#     },
#     "total_orders": 2,
#     "month": 3,
#     "store_name": "La Verdad"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "60abca42c4354a1c628ca314"
#     },
#     "total_orders": 34,
#     "month": 3,
#     "store_name": "Lakeshore Cafe"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "63208ee5a7d7d40f864cde37"
#     },
#     "total_orders": 7,
#     "month": 3,
#     "store_name": "Lime House Sushi & Ramen | Hamburg"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "5ffdbf7e5465ff35ee3cd414"
#     },
#     "total_orders": 6,
#     "month": 3,
#     "store_name": "Louie's Texas Red Hots - Orchard Park "
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "5fcbb4e054c1706025d59aae"
#     },
#     "total_orders": 2,
#     "month": 3,
#     "store_name": "Marco\u2019s Italian Restaurant "
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "64b6c970e2bd6e48353ec919"
#     },
#     "total_orders": 3,
#     "month": 3,
#     "store_name": "Mario's Bistro & Brews"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "6214f1ecb93c4f44247387a9"
#     },
#     "total_orders": 14,
#     "month": 3,
#     "store_name": "Milk & Tea"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "5fca95755db8af8a2ca5c19b"
#     },
#     "total_orders": 23,
#     "month": 3,
#     "store_name": "Off The Wall Sandwich Company"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "640623750de38a7b959b6a0a"
#     },
#     "total_orders": 1,
#     "month": 3,
#     "store_name": "Old Orchard Inn"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "6544d1c8ebde7d15e2e7cf13"
#     },
#     "total_orders": 2,
#     "month": 3,
#     "store_name": "Pham's Kitchen"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "602d2d8263b7e5c183f269be"
#     },
#     "total_orders": 10,
#     "month": 3,
#     "store_name": "Pizza Plant Transit"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "62308c07e360923779cc8053"
#     },
#     "total_orders": 21,
#     "month": 3,
#     "store_name": "Rin Thai Bistro"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "618027873904904abf8f9ff7"
#     },
#     "total_orders": 32,
#     "month": 3,
#     "store_name": "Sports City Pizza Pub"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "6350035aaf0c66c48da29d93"
#     },
#     "total_orders": 18,
#     "month": 3,
#     "store_name": "The Grange Outpost"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "6579ee1925523d220c9959ca"
#     },
#     "total_orders": 16,
#     "month": 3,
#     "store_name": "The Ridge West Seneca"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "5fbcffb9e59b5518a91a66fe"
#     },
#     "total_orders": 9,
#     "month": 3,
#     "store_name": "Undergrounds Coffee House and Roastery "
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "609033cb7bc821c6efe810d3"
#     },
#     "total_orders": 1,
#     "month": 3,
#     "store_name": "VinLouie's"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "61b8dad221a96859e2c43133"
#     },
#     "total_orders": 22,
#     "month": 3,
#     "store_name": "Voula's Greek Sweets"
#   },
#   {
#     "_id": {
#       "month": 3,
#       "store_id": "63e143fc0de38a94a99a7559"
#     },
#     "total_orders": 6,
#     "month": 3,
#     "store_name": "Winfield's Pub"
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "5ffe033b5465ffa6c93cde70"
#     },
#     "total_orders": 43,
#     "month": 4,
#     "store_name": "Aguacates Mexican Bar & Grill | Elmwood"
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "5fa42c8d7cc0c3189e350a3b"
#     },
#     "total_orders": 5,
#     "month": 4,
#     "store_name": "Allentown Pizza"
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "5fb5bf5934d2dc3679565cac"
#     },
#     "total_orders": 27,
#     "month": 4,
#     "store_name": "Ballyhoo"
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "64fb74ecd347663f1e74be2c"
#     },
#     "total_orders": 46,
#     "month": 4,
#     "store_name": "Buffalo Deep Dish"
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "5fb57c6e34d2dc77f8565a76"
#     },
#     "total_orders": 13,
#     "month": 4,
#     "store_name": "Butera's Craft Beer & Craft Pizza"
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "5fc5707c0642fe105f7bf56d"
#     },
#     "total_orders": 46,
#     "month": 4,
#     "store_name": "Cafe 59"
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "5f9c37a75c9bb54266ffafc1"
#     },
#     "total_orders": 4,
#     "month": 4,
#     "store_name": "Colter Bay"
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "5fa18d605c9bb56497ffb1ee"
#     },
#     "total_orders": 26,
#     "month": 4,
#     "store_name": "Fat Bob's Smokehouse"
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "6384da2ef82eb777db9fd0f7"
#     },
#     "total_orders": 7,
#     "month": 4,
#     "store_name": "Giacobbi's Cucina Citta"
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "5fda363171684a8075618c44"
#     },
#     "total_orders": 23,
#     "month": 4,
#     "store_name": "Glen Park Tavern "
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "6422ecc5a7f10a43c4ff6baf"
#     },
#     "total_orders": 23,
#     "month": 4,
#     "store_name": "Grass Fed Vegan Butcher Shop"
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "61548c5d382e639bac6f3eb6"
#     },
#     "total_orders": 1,
#     "month": 4,
#     "store_name": "Hombre Y Lobo"
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "603aa3bda246a7772f08ce25"
#     },
#     "total_orders": 1,
#     "month": 4,
#     "store_name": "India Gate"
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "638f9b40f82eb70394a005f7"
#     },
#     "total_orders": 72,
#     "month": 4,
#     "store_name": "K Dara Noodle Bar"
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "6567471925523d16798c60ea"
#     },
#     "total_orders": 2,
#     "month": 4,
#     "store_name": "La Verdad"
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "60abca42c4354a1c628ca314"
#     },
#     "total_orders": 28,
#     "month": 4,
#     "store_name": "Lakeshore Cafe"
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "63208ee5a7d7d40f864cde37"
#     },
#     "total_orders": 3,
#     "month": 4,
#     "store_name": "Lime House Sushi & Ramen | Hamburg"
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "5ffdbf7e5465ff35ee3cd414"
#     },
#     "total_orders": 7,
#     "month": 4,
#     "store_name": "Louie's Texas Red Hots - Orchard Park "
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "6214f1ecb93c4f44247387a9"
#     },
#     "total_orders": 15,
#     "month": 4,
#     "store_name": "Milk & Tea"
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "65e9066b382f3824eaba3fe3"
#     },
#     "total_orders": 1,
#     "month": 4,
#     "store_name": "Mister Pizza | Elmwood"
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "5fca95755db8af8a2ca5c19b"
#     },
#     "total_orders": 28,
#     "month": 4,
#     "store_name": "Off The Wall Sandwich Company"
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "6544d1c8ebde7d15e2e7cf13"
#     },
#     "total_orders": 5,
#     "month": 4,
#     "store_name": "Pham's Kitchen"
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "602d2d8263b7e5c183f269be"
#     },
#     "total_orders": 7,
#     "month": 4,
#     "store_name": "Pizza Plant Transit"
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "62308c07e360923779cc8053"
#     },
#     "total_orders": 11,
#     "month": 4,
#     "store_name": "Rin Thai Bistro"
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "618027873904904abf8f9ff7"
#     },
#     "total_orders": 16,
#     "month": 4,
#     "store_name": "Sports City Pizza Pub"
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "6350035aaf0c66c48da29d93"
#     },
#     "total_orders": 13,
#     "month": 4,
#     "store_name": "The Grange Outpost"
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "6579ee1925523d220c9959ca"
#     },
#     "total_orders": 13,
#     "month": 4,
#     "store_name": "The Ridge West Seneca"
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "5fbcffb9e59b5518a91a66fe"
#     },
#     "total_orders": 4,
#     "month": 4,
#     "store_name": "Undergrounds Coffee House and Roastery "
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "609033cb7bc821c6efe810d3"
#     },
#     "total_orders": 1,
#     "month": 4,
#     "store_name": "VinLouie's"
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "61b8dad221a96859e2c43133"
#     },
#     "total_orders": 25,
#     "month": 4,
#     "store_name": "Voula's Greek Sweets"
#   },
#   {
#     "_id": {
#       "month": 4,
#       "store_id": "63e143fc0de38a94a99a7559"
#     },
#     "total_orders": 4,
#     "month": 4,
#     "store_name": "Winfield's Pub"
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "5ffe033b5465ffa6c93cde70"
#     },
#     "total_orders": 35,
#     "month": 5,
#     "store_name": "Aguacates Mexican Bar & Grill | Elmwood"
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "5fa42c8d7cc0c3189e350a3b"
#     },
#     "total_orders": 3,
#     "month": 5,
#     "store_name": "Allentown Pizza"
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "5fb5bf5934d2dc3679565cac"
#     },
#     "total_orders": 20,
#     "month": 5,
#     "store_name": "Ballyhoo"
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "64fb74ecd347663f1e74be2c"
#     },
#     "total_orders": 80,
#     "month": 5,
#     "store_name": "Buffalo Deep Dish"
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "5fb57c6e34d2dc77f8565a76"
#     },
#     "total_orders": 13,
#     "month": 5,
#     "store_name": "Butera's Craft Beer & Craft Pizza"
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "5fc5707c0642fe105f7bf56d"
#     },
#     "total_orders": 48,
#     "month": 5,
#     "store_name": "Cafe 59"
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "5fa18d605c9bb56497ffb1ee"
#     },
#     "total_orders": 43,
#     "month": 5,
#     "store_name": "Fat Bob's Smokehouse"
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "6384da2ef82eb777db9fd0f7"
#     },
#     "total_orders": 7,
#     "month": 5,
#     "store_name": "Giacobbi's Cucina Citta"
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "5fda363171684a8075618c44"
#     },
#     "total_orders": 25,
#     "month": 5,
#     "store_name": "Glen Park Tavern "
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "6422ecc5a7f10a43c4ff6baf"
#     },
#     "total_orders": 42,
#     "month": 5,
#     "store_name": "Grass Fed Vegan Butcher Shop"
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "603aa3bda246a7772f08ce25"
#     },
#     "total_orders": 4,
#     "month": 5,
#     "store_name": "India Gate"
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "638f9b40f82eb70394a005f7"
#     },
#     "total_orders": 64,
#     "month": 5,
#     "store_name": "K Dara Noodle Bar"
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "6567471925523d16798c60ea"
#     },
#     "total_orders": 2,
#     "month": 5,
#     "store_name": "La Verdad"
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "60abca42c4354a1c628ca314"
#     },
#     "total_orders": 29,
#     "month": 5,
#     "store_name": "Lakeshore Cafe"
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "63208ee5a7d7d40f864cde37"
#     },
#     "total_orders": 7,
#     "month": 5,
#     "store_name": "Lime House Sushi & Ramen | Hamburg"
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "5ffdbf7e5465ff35ee3cd414"
#     },
#     "total_orders": 9,
#     "month": 5,
#     "store_name": "Louie's Texas Red Hots - Orchard Park "
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "5fcbb4e054c1706025d59aae"
#     },
#     "total_orders": 2,
#     "month": 5,
#     "store_name": "Marco\u2019s Italian Restaurant "
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "6214f1ecb93c4f44247387a9"
#     },
#     "total_orders": 8,
#     "month": 5,
#     "store_name": "Milk & Tea"
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "65e9066b382f3824eaba3fe3"
#     },
#     "total_orders": 2,
#     "month": 5,
#     "store_name": "Mister Pizza | Elmwood"
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "5fca95755db8af8a2ca5c19b"
#     },
#     "total_orders": 35,
#     "month": 5,
#     "store_name": "Off The Wall Sandwich Company"
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "6544d1c8ebde7d15e2e7cf13"
#     },
#     "total_orders": 1,
#     "month": 5,
#     "store_name": "Pham's Kitchen"
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "602d2d8263b7e5c183f269be"
#     },
#     "total_orders": 8,
#     "month": 5,
#     "store_name": "Pizza Plant Transit"
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "62308c07e360923779cc8053"
#     },
#     "total_orders": 10,
#     "month": 5,
#     "store_name": "Rin Thai Bistro"
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "618027873904904abf8f9ff7"
#     },
#     "total_orders": 22,
#     "month": 5,
#     "store_name": "Sports City Pizza Pub"
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "6350035aaf0c66c48da29d93"
#     },
#     "total_orders": 13,
#     "month": 5,
#     "store_name": "The Grange Outpost"
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "6579ee1925523d220c9959ca"
#     },
#     "total_orders": 18,
#     "month": 5,
#     "store_name": "The Ridge West Seneca"
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "5fbcffb9e59b5518a91a66fe"
#     },
#     "total_orders": 1,
#     "month": 5,
#     "store_name": "Undergrounds Coffee House and Roastery "
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "609033cb7bc821c6efe810d3"
#     },
#     "total_orders": 2,
#     "month": 5,
#     "store_name": "VinLouie's"
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "61b8dad221a96859e2c43133"
#     },
#     "total_orders": 25,
#     "month": 5,
#     "store_name": "Voula's Greek Sweets"
#   },
#   {
#     "_id": {
#       "month": 5,
#       "store_id": "63e143fc0de38a94a99a7559"
#     },
#     "total_orders": 4,
#     "month": 5,
#     "store_name": "Winfield's Pub"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "5ffe033b5465ffa6c93cde70"
#     },
#     "total_orders": 34,
#     "month": 6,
#     "store_name": "Aguacates Mexican Bar & Grill | Elmwood"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "5fa42c8d7cc0c3189e350a3b"
#     },
#     "total_orders": 2,
#     "month": 6,
#     "store_name": "Allentown Pizza"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "5fb5bf5934d2dc3679565cac"
#     },
#     "total_orders": 21,
#     "month": 6,
#     "store_name": "Ballyhoo"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "65f38e0c382f38abb6c3111e"
#     },
#     "total_orders": 5,
#     "month": 6,
#     "store_name": "Blue Eyed Baker"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "64fb74ecd347663f1e74be2c"
#     },
#     "total_orders": 65,
#     "month": 6,
#     "store_name": "Buffalo Deep Dish"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "5fb57c6e34d2dc77f8565a76"
#     },
#     "total_orders": 10,
#     "month": 6,
#     "store_name": "Butera's Craft Beer & Craft Pizza"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "5fc5707c0642fe105f7bf56d"
#     },
#     "total_orders": 42,
#     "month": 6,
#     "store_name": "Cafe 59"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "5f9c37a75c9bb54266ffafc1"
#     },
#     "total_orders": 1,
#     "month": 6,
#     "store_name": "Colter Bay"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "5fa18d605c9bb56497ffb1ee"
#     },
#     "total_orders": 45,
#     "month": 6,
#     "store_name": "Fat Bob's Smokehouse"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "6384da2ef82eb777db9fd0f7"
#     },
#     "total_orders": 9,
#     "month": 6,
#     "store_name": "Giacobbi's Cucina Citta"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "5fda363171684a8075618c44"
#     },
#     "total_orders": 27,
#     "month": 6,
#     "store_name": "Glen Park Tavern "
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "6422ecc5a7f10a43c4ff6baf"
#     },
#     "total_orders": 30,
#     "month": 6,
#     "store_name": "Grass Fed Vegan Butcher Shop"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "61548c5d382e639bac6f3eb6"
#     },
#     "total_orders": 3,
#     "month": 6,
#     "store_name": "Hombre Y Lobo"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "603aa3bda246a7772f08ce25"
#     },
#     "total_orders": 3,
#     "month": 6,
#     "store_name": "India Gate"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "638f9b40f82eb70394a005f7"
#     },
#     "total_orders": 61,
#     "month": 6,
#     "store_name": "K Dara Noodle Bar"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "60abca42c4354a1c628ca314"
#     },
#     "total_orders": 27,
#     "month": 6,
#     "store_name": "Lakeshore Cafe"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "63208ee5a7d7d40f864cde37"
#     },
#     "total_orders": 6,
#     "month": 6,
#     "store_name": "Lime House Sushi & Ramen | Hamburg"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "5ffdbf7e5465ff35ee3cd414"
#     },
#     "total_orders": 10,
#     "month": 6,
#     "store_name": "Louie's Texas Red Hots - Orchard Park "
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "6669f3a1230c244ffc63b87b"
#     },
#     "total_orders": 2,
#     "month": 6,
#     "store_name": "Malkia and Co."
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "5fcbb4e054c1706025d59aae"
#     },
#     "total_orders": 3,
#     "month": 6,
#     "store_name": "Marco\u2019s Italian Restaurant "
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "64b6c970e2bd6e48353ec919"
#     },
#     "total_orders": 1,
#     "month": 6,
#     "store_name": "Mario's Bistro & Brews"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "6214f1ecb93c4f44247387a9"
#     },
#     "total_orders": 3,
#     "month": 6,
#     "store_name": "Milk & Tea"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "5fca95755db8af8a2ca5c19b"
#     },
#     "total_orders": 21,
#     "month": 6,
#     "store_name": "Off The Wall Sandwich Company"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "640623750de38a7b959b6a0a"
#     },
#     "total_orders": 1,
#     "month": 6,
#     "store_name": "Old Orchard Inn"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "6544d1c8ebde7d15e2e7cf13"
#     },
#     "total_orders": 2,
#     "month": 6,
#     "store_name": "Pham's Kitchen"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "602d2d8263b7e5c183f269be"
#     },
#     "total_orders": 11,
#     "month": 6,
#     "store_name": "Pizza Plant Transit"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "62308c07e360923779cc8053"
#     },
#     "total_orders": 9,
#     "month": 6,
#     "store_name": "Rin Thai Bistro"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "618027873904904abf8f9ff7"
#     },
#     "total_orders": 15,
#     "month": 6,
#     "store_name": "Sports City Pizza Pub"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "6350035aaf0c66c48da29d93"
#     },
#     "total_orders": 13,
#     "month": 6,
#     "store_name": "The Grange Outpost"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "6579ee1925523d220c9959ca"
#     },
#     "total_orders": 22,
#     "month": 6,
#     "store_name": "The Ridge West Seneca"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "5fbcffb9e59b5518a91a66fe"
#     },
#     "total_orders": 1,
#     "month": 6,
#     "store_name": "Undergrounds Coffee House and Roastery "
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "609033cb7bc821c6efe810d3"
#     },
#     "total_orders": 1,
#     "month": 6,
#     "store_name": "VinLouie's"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "61b8dad221a96859e2c43133"
#     },
#     "total_orders": 26,
#     "month": 6,
#     "store_name": "Voula's Greek Sweets"
#   },
#   {
#     "_id": {
#       "month": 6,
#       "store_id": "63e143fc0de38a94a99a7559"
#     },
#     "total_orders": 3,
#     "month": 6,
#     "store_name": "Winfield's Pub"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "5ffe033b5465ffa6c93cde70"
#     },
#     "total_orders": 14,
#     "month": 7,
#     "store_name": "Aguacates Mexican Bar & Grill | Elmwood"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "5fa42c8d7cc0c3189e350a3b"
#     },
#     "total_orders": 1,
#     "month": 7,
#     "store_name": "Allentown Pizza"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "5fb5bf5934d2dc3679565cac"
#     },
#     "total_orders": 17,
#     "month": 7,
#     "store_name": "Ballyhoo"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "65f38e0c382f38abb6c3111e"
#     },
#     "total_orders": 9,
#     "month": 7,
#     "store_name": "Blue Eyed Baker"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "64fb74ecd347663f1e74be2c"
#     },
#     "total_orders": 44,
#     "month": 7,
#     "store_name": "Buffalo Deep Dish"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "5fb57c6e34d2dc77f8565a76"
#     },
#     "total_orders": 10,
#     "month": 7,
#     "store_name": "Butera's Craft Beer & Craft Pizza"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "5fc5707c0642fe105f7bf56d"
#     },
#     "total_orders": 46,
#     "month": 7,
#     "store_name": "Cafe 59"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "6650bae5230c248c894e1c92"
#     },
#     "total_orders": 18,
#     "month": 7,
#     "store_name": "Chef Bigwayne Jamaican Cuisine"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "5fa18d605c9bb56497ffb1ee"
#     },
#     "total_orders": 19,
#     "month": 7,
#     "store_name": "Fat Bob's Smokehouse"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "6384da2ef82eb777db9fd0f7"
#     },
#     "total_orders": 8,
#     "month": 7,
#     "store_name": "Giacobbi's Cucina Citta"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "5fda363171684a8075618c44"
#     },
#     "total_orders": 20,
#     "month": 7,
#     "store_name": "Glen Park Tavern "
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "6422ecc5a7f10a43c4ff6baf"
#     },
#     "total_orders": 23,
#     "month": 7,
#     "store_name": "Grass Fed Vegan Butcher Shop"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "61548c5d382e639bac6f3eb6"
#     },
#     "total_orders": 1,
#     "month": 7,
#     "store_name": "Hombre Y Lobo"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "603aa3bda246a7772f08ce25"
#     },
#     "total_orders": 2,
#     "month": 7,
#     "store_name": "India Gate"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "638f9b40f82eb70394a005f7"
#     },
#     "total_orders": 15,
#     "month": 7,
#     "store_name": "K Dara Noodle Bar"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "6567471925523d16798c60ea"
#     },
#     "total_orders": 1,
#     "month": 7,
#     "store_name": "La Verdad"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "60abca42c4354a1c628ca314"
#     },
#     "total_orders": 23,
#     "month": 7,
#     "store_name": "Lakeshore Cafe"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "63208ee5a7d7d40f864cde37"
#     },
#     "total_orders": 7,
#     "month": 7,
#     "store_name": "Lime House Sushi & Ramen | Hamburg"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "5ffdbf7e5465ff35ee3cd414"
#     },
#     "total_orders": 14,
#     "month": 7,
#     "store_name": "Louie's Texas Red Hots - Orchard Park "
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "6669f3a1230c244ffc63b87b"
#     },
#     "total_orders": 3,
#     "month": 7,
#     "store_name": "Malkia and Co."
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "64b6c970e2bd6e48353ec919"
#     },
#     "total_orders": 6,
#     "month": 7,
#     "store_name": "Mario's Bistro & Brews"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "6214f1ecb93c4f44247387a9"
#     },
#     "total_orders": 1,
#     "month": 7,
#     "store_name": "Milk & Tea"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "65e9066b382f3824eaba3fe3"
#     },
#     "total_orders": 1,
#     "month": 7,
#     "store_name": "Mister Pizza | Elmwood"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "668d46be230c2480447b7772"
#     },
#     "total_orders": 2,
#     "month": 7,
#     "store_name": "O'Brien's West End"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "5fca95755db8af8a2ca5c19b"
#     },
#     "total_orders": 16,
#     "month": 7,
#     "store_name": "Off The Wall Sandwich Company"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "640623750de38a7b959b6a0a"
#     },
#     "total_orders": 4,
#     "month": 7,
#     "store_name": "Old Orchard Inn"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "66854adc230c2416d875e4f1"
#     },
#     "total_orders": 3,
#     "month": 7,
#     "store_name": "Oralia"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "6669f42c230c24435c63b8cc"
#     },
#     "total_orders": 6,
#     "month": 7,
#     "store_name": "Phyu Thein"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "602d2d8263b7e5c183f269be"
#     },
#     "total_orders": 7,
#     "month": 7,
#     "store_name": "Pizza Plant Transit"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "62308c07e360923779cc8053"
#     },
#     "total_orders": 10,
#     "month": 7,
#     "store_name": "Rin Thai Bistro"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "618027873904904abf8f9ff7"
#     },
#     "total_orders": 11,
#     "month": 7,
#     "store_name": "Sports City Pizza Pub"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "6350035aaf0c66c48da29d93"
#     },
#     "total_orders": 5,
#     "month": 7,
#     "store_name": "The Grange Outpost"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "6579ee1925523d220c9959ca"
#     },
#     "total_orders": 20,
#     "month": 7,
#     "store_name": "The Ridge West Seneca"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "5fbcffb9e59b5518a91a66fe"
#     },
#     "total_orders": 2,
#     "month": 7,
#     "store_name": "Undergrounds Coffee House and Roastery "
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "61b8dad221a96859e2c43133"
#     },
#     "total_orders": 17,
#     "month": 7,
#     "store_name": "Voula's Greek Sweets"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "66841431230c24345b74adea"
#     },
#     "total_orders": 8,
#     "month": 7,
#     "store_name": "William's Kitchen"
#   },
#   {
#     "_id": {
#       "month": 7,
#       "store_id": "63e143fc0de38a94a99a7559"
#     },
#     "total_orders": 5,
#     "month": 7,
#     "store_name": "Winfield's Pub"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "5ffe033b5465ffa6c93cde70"
#     },
#     "total_orders": 12,
#     "month": 8,
#     "store_name": "Aguacates Mexican Bar & Grill | Elmwood"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "5fa42c8d7cc0c3189e350a3b"
#     },
#     "total_orders": 2,
#     "month": 8,
#     "store_name": "Allentown Pizza"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "5fb5bf5934d2dc3679565cac"
#     },
#     "total_orders": 15,
#     "month": 8,
#     "store_name": "Ballyhoo"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "65f38e0c382f38abb6c3111e"
#     },
#     "total_orders": 5,
#     "month": 8,
#     "store_name": "Blue Eyed Baker"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "64fb74ecd347663f1e74be2c"
#     },
#     "total_orders": 56,
#     "month": 8,
#     "store_name": "Buffalo Deep Dish"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "5fb57c6e34d2dc77f8565a76"
#     },
#     "total_orders": 5,
#     "month": 8,
#     "store_name": "Butera's Craft Beer & Craft Pizza"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "5fc5707c0642fe105f7bf56d"
#     },
#     "total_orders": 31,
#     "month": 8,
#     "store_name": "Cafe 59"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "6650bae5230c248c894e1c92"
#     },
#     "total_orders": 38,
#     "month": 8,
#     "store_name": "Chef Bigwayne Jamaican Cuisine"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "5f9c37a75c9bb54266ffafc1"
#     },
#     "total_orders": 4,
#     "month": 8,
#     "store_name": "Colter Bay"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "5fa18d605c9bb56497ffb1ee"
#     },
#     "total_orders": 22,
#     "month": 8,
#     "store_name": "Fat Bob's Smokehouse"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "6384da2ef82eb777db9fd0f7"
#     },
#     "total_orders": 5,
#     "month": 8,
#     "store_name": "Giacobbi's Cucina Citta"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "5fda363171684a8075618c44"
#     },
#     "total_orders": 20,
#     "month": 8,
#     "store_name": "Glen Park Tavern "
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "6422ecc5a7f10a43c4ff6baf"
#     },
#     "total_orders": 21,
#     "month": 8,
#     "store_name": "Grass Fed Vegan Butcher Shop"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "60abca42c4354a1c628ca314"
#     },
#     "total_orders": 21,
#     "month": 8,
#     "store_name": "Lakeshore Cafe"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "63208ee5a7d7d40f864cde37"
#     },
#     "total_orders": 4,
#     "month": 8,
#     "store_name": "Lime House Sushi & Ramen | Hamburg"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "5ffdbf7e5465ff35ee3cd414"
#     },
#     "total_orders": 15,
#     "month": 8,
#     "store_name": "Louie's Texas Red Hots - Orchard Park "
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "6669f3a1230c244ffc63b87b"
#     },
#     "total_orders": 1,
#     "month": 8,
#     "store_name": "Malkia and Co."
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "5fcbb4e054c1706025d59aae"
#     },
#     "total_orders": 2,
#     "month": 8,
#     "store_name": "Marco\u2019s Italian Restaurant "
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "64b6c970e2bd6e48353ec919"
#     },
#     "total_orders": 4,
#     "month": 8,
#     "store_name": "Mario's Bistro & Brews"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "6214f1ecb93c4f44247387a9"
#     },
#     "total_orders": 1,
#     "month": 8,
#     "store_name": "Milk & Tea"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "65e9066b382f3824eaba3fe3"
#     },
#     "total_orders": 1,
#     "month": 8,
#     "store_name": "Mister Pizza | Elmwood"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "668d46be230c2480447b7772"
#     },
#     "total_orders": 10,
#     "month": 8,
#     "store_name": "O'Brien's West End"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "5fca95755db8af8a2ca5c19b"
#     },
#     "total_orders": 15,
#     "month": 8,
#     "store_name": "Off The Wall Sandwich Company"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "640623750de38a7b959b6a0a"
#     },
#     "total_orders": 1,
#     "month": 8,
#     "store_name": "Old Orchard Inn"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "6544d1c8ebde7d15e2e7cf13"
#     },
#     "total_orders": 3,
#     "month": 8,
#     "store_name": "Pham's Kitchen"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "6669f42c230c24435c63b8cc"
#     },
#     "total_orders": 8,
#     "month": 8,
#     "store_name": "Phyu Thein"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "602d2d8263b7e5c183f269be"
#     },
#     "total_orders": 10,
#     "month": 8,
#     "store_name": "Pizza Plant Transit"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "62308c07e360923779cc8053"
#     },
#     "total_orders": 9,
#     "month": 8,
#     "store_name": "Rin Thai Bistro"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "618027873904904abf8f9ff7"
#     },
#     "total_orders": 15,
#     "month": 8,
#     "store_name": "Sports City Pizza Pub"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "6350035aaf0c66c48da29d93"
#     },
#     "total_orders": 8,
#     "month": 8,
#     "store_name": "The Grange Outpost"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "6579ee1925523d220c9959ca"
#     },
#     "total_orders": 23,
#     "month": 8,
#     "store_name": "The Ridge West Seneca"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "5fbcffb9e59b5518a91a66fe"
#     },
#     "total_orders": 3,
#     "month": 8,
#     "store_name": "Undergrounds Coffee House and Roastery "
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "609033cb7bc821c6efe810d3"
#     },
#     "total_orders": 2,
#     "month": 8,
#     "store_name": "VinLouie's"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "61b8dad221a96859e2c43133"
#     },
#     "total_orders": 18,
#     "month": 8,
#     "store_name": "Voula's Greek Sweets"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "66841431230c24345b74adea"
#     },
#     "total_orders": 23,
#     "month": 8,
#     "store_name": "William's Kitchen"
#   },
#   {
#     "_id": {
#       "month": 8,
#       "store_id": "63e143fc0de38a94a99a7559"
#     },
#     "total_orders": 5,
#     "month": 8,
#     "store_name": "Winfield's Pub"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "5ffe033b5465ffa6c93cde70"
#     },
#     "total_orders": 13,
#     "month": 9,
#     "store_name": "Aguacates Mexican Bar & Grill | Elmwood"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "5fa42c8d7cc0c3189e350a3b"
#     },
#     "total_orders": 1,
#     "month": 9,
#     "store_name": "Allentown Pizza"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "5fb5bf5934d2dc3679565cac"
#     },
#     "total_orders": 15,
#     "month": 9,
#     "store_name": "Ballyhoo"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "65f38e0c382f38abb6c3111e"
#     },
#     "total_orders": 7,
#     "month": 9,
#     "store_name": "Blue Eyed Baker"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "64fb74ecd347663f1e74be2c"
#     },
#     "total_orders": 43,
#     "month": 9,
#     "store_name": "Buffalo Deep Dish"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "5fb57c6e34d2dc77f8565a76"
#     },
#     "total_orders": 4,
#     "month": 9,
#     "store_name": "Butera's Craft Beer & Craft Pizza"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "5fc5707c0642fe105f7bf56d"
#     },
#     "total_orders": 42,
#     "month": 9,
#     "store_name": "Cafe 59"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "6650bae5230c248c894e1c92"
#     },
#     "total_orders": 29,
#     "month": 9,
#     "store_name": "Chef Bigwayne Jamaican Cuisine"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "5f9c37a75c9bb54266ffafc1"
#     },
#     "total_orders": 2,
#     "month": 9,
#     "store_name": "Colter Bay"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "66df28b51c49f819d9b36f74"
#     },
#     "total_orders": 3,
#     "month": 9,
#     "store_name": "Cristos Wood Fired Pizza & Pasta"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "5fa18d605c9bb56497ffb1ee"
#     },
#     "total_orders": 20,
#     "month": 9,
#     "store_name": "Fat Bob's Smokehouse"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "6384da2ef82eb777db9fd0f7"
#     },
#     "total_orders": 6,
#     "month": 9,
#     "store_name": "Giacobbi's Cucina Citta"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "5fda363171684a8075618c44"
#     },
#     "total_orders": 30,
#     "month": 9,
#     "store_name": "Glen Park Tavern "
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "6422ecc5a7f10a43c4ff6baf"
#     },
#     "total_orders": 16,
#     "month": 9,
#     "store_name": "Grass Fed Vegan Butcher Shop"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "61548c5d382e639bac6f3eb6"
#     },
#     "total_orders": 1,
#     "month": 9,
#     "store_name": "Hombre Y Lobo"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "60abca42c4354a1c628ca314"
#     },
#     "total_orders": 20,
#     "month": 9,
#     "store_name": "Lakeshore Cafe"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "63208ee5a7d7d40f864cde37"
#     },
#     "total_orders": 6,
#     "month": 9,
#     "store_name": "Lime House Sushi & Ramen | Hamburg"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "5ffdbf7e5465ff35ee3cd414"
#     },
#     "total_orders": 8,
#     "month": 9,
#     "store_name": "Louie's Texas Red Hots - Orchard Park "
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "6669f3a1230c244ffc63b87b"
#     },
#     "total_orders": 5,
#     "month": 9,
#     "store_name": "Malkia and Co."
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "5fcbb4e054c1706025d59aae"
#     },
#     "total_orders": 3,
#     "month": 9,
#     "store_name": "Marco\u2019s Italian Restaurant "
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "64b6c970e2bd6e48353ec919"
#     },
#     "total_orders": 4,
#     "month": 9,
#     "store_name": "Mario's Bistro & Brews"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "6214f1ecb93c4f44247387a9"
#     },
#     "total_orders": 5,
#     "month": 9,
#     "store_name": "Milk & Tea"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "668d46be230c2480447b7772"
#     },
#     "total_orders": 11,
#     "month": 9,
#     "store_name": "O'Brien's West End"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "5fca95755db8af8a2ca5c19b"
#     },
#     "total_orders": 26,
#     "month": 9,
#     "store_name": "Off The Wall Sandwich Company"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "6544d1c8ebde7d15e2e7cf13"
#     },
#     "total_orders": 4,
#     "month": 9,
#     "store_name": "Pham's Kitchen"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "6669f42c230c24435c63b8cc"
#     },
#     "total_orders": 7,
#     "month": 9,
#     "store_name": "Phyu Thein"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "602d2d8263b7e5c183f269be"
#     },
#     "total_orders": 2,
#     "month": 9,
#     "store_name": "Pizza Plant Transit"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "62308c07e360923779cc8053"
#     },
#     "total_orders": 7,
#     "month": 9,
#     "store_name": "Rin Thai Bistro"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "618027873904904abf8f9ff7"
#     },
#     "total_orders": 19,
#     "month": 9,
#     "store_name": "Sports City Pizza Pub"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "6350035aaf0c66c48da29d93"
#     },
#     "total_orders": 5,
#     "month": 9,
#     "store_name": "The Grange Outpost"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "6579ee1925523d220c9959ca"
#     },
#     "total_orders": 5,
#     "month": 9,
#     "store_name": "The Ridge West Seneca"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "66c74fe7bea643fc4b12caf0"
#     },
#     "total_orders": 2,
#     "month": 9,
#     "store_name": "Two Nines Kitchen & Bar"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "5fbcffb9e59b5518a91a66fe"
#     },
#     "total_orders": 3,
#     "month": 9,
#     "store_name": "Undergrounds Coffee House and Roastery "
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "61b8dad221a96859e2c43133"
#     },
#     "total_orders": 23,
#     "month": 9,
#     "store_name": "Voula's Greek Sweets"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "66841431230c24345b74adea"
#     },
#     "total_orders": 18,
#     "month": 9,
#     "store_name": "William's Kitchen"
#   },
#   {
#     "_id": {
#       "month": 9,
#       "store_id": "63e143fc0de38a94a99a7559"
#     },
#     "total_orders": 7,
#     "month": 9,
#     "store_name": "Winfield's Pub"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "5ffe033b5465ffa6c93cde70"
#     },
#     "total_orders": 25,
#     "month": 10,
#     "store_name": "Aguacates Mexican Bar & Grill | Elmwood"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "5fa42c8d7cc0c3189e350a3b"
#     },
#     "total_orders": 2,
#     "month": 10,
#     "store_name": "Allentown Pizza"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "5fb5bf5934d2dc3679565cac"
#     },
#     "total_orders": 13,
#     "month": 10,
#     "store_name": "Ballyhoo"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "65f38e0c382f38abb6c3111e"
#     },
#     "total_orders": 1,
#     "month": 10,
#     "store_name": "Blue Eyed Baker"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "64fb74ecd347663f1e74be2c"
#     },
#     "total_orders": 48,
#     "month": 10,
#     "store_name": "Buffalo Deep Dish"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "5fb57c6e34d2dc77f8565a76"
#     },
#     "total_orders": 12,
#     "month": 10,
#     "store_name": "Butera's Craft Beer & Craft Pizza"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "5fc5707c0642fe105f7bf56d"
#     },
#     "total_orders": 40,
#     "month": 10,
#     "store_name": "Cafe 59"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "6650bae5230c248c894e1c92"
#     },
#     "total_orders": 17,
#     "month": 10,
#     "store_name": "Chef Bigwayne Jamaican Cuisine"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "5f9c37a75c9bb54266ffafc1"
#     },
#     "total_orders": 1,
#     "month": 10,
#     "store_name": "Colter Bay"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "66df28b51c49f819d9b36f74"
#     },
#     "total_orders": 8,
#     "month": 10,
#     "store_name": "Cristos Wood Fired Pizza & Pasta"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "671a52a2a81cf2b25e485b66"
#     },
#     "total_orders": 2,
#     "month": 10,
#     "store_name": "Egyptian Bites"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "5fa18d605c9bb56497ffb1ee"
#     },
#     "total_orders": 22,
#     "month": 10,
#     "store_name": "Fat Bob's Smokehouse"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "6384da2ef82eb777db9fd0f7"
#     },
#     "total_orders": 5,
#     "month": 10,
#     "store_name": "Giacobbi's Cucina Citta"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "5fda363171684a8075618c44"
#     },
#     "total_orders": 31,
#     "month": 10,
#     "store_name": "Glen Park Tavern "
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "6422ecc5a7f10a43c4ff6baf"
#     },
#     "total_orders": 21,
#     "month": 10,
#     "store_name": "Grass Fed Vegan Butcher Shop"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "63cfefbd415cbf4fcae7a83a"
#     },
#     "total_orders": 1,
#     "month": 10,
#     "store_name": "Hanzlian's Homemade Sausage"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "6567471925523d16798c60ea"
#     },
#     "total_orders": 1,
#     "month": 10,
#     "store_name": "La Verdad"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "60abca42c4354a1c628ca314"
#     },
#     "total_orders": 19,
#     "month": 10,
#     "store_name": "Lakeshore Cafe"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "63208ee5a7d7d40f864cde37"
#     },
#     "total_orders": 2,
#     "month": 10,
#     "store_name": "Lime House Sushi & Ramen | Hamburg"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "5ffdbf7e5465ff35ee3cd414"
#     },
#     "total_orders": 8,
#     "month": 10,
#     "store_name": "Louie's Texas Red Hots - Orchard Park "
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "6669f3a1230c244ffc63b87b"
#     },
#     "total_orders": 4,
#     "month": 10,
#     "store_name": "Malkia and Co."
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "5fcbb4e054c1706025d59aae"
#     },
#     "total_orders": 3,
#     "month": 10,
#     "store_name": "Marco\u2019s Italian Restaurant "
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "64b6c970e2bd6e48353ec919"
#     },
#     "total_orders": 1,
#     "month": 10,
#     "store_name": "Mario's Bistro & Brews"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "6214f1ecb93c4f44247387a9"
#     },
#     "total_orders": 4,
#     "month": 10,
#     "store_name": "Milk & Tea"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "65e9066b382f3824eaba3fe3"
#     },
#     "total_orders": 2,
#     "month": 10,
#     "store_name": "Mister Pizza | Elmwood"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "668d46be230c2480447b7772"
#     },
#     "total_orders": 23,
#     "month": 10,
#     "store_name": "O'Brien's West End"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "5fca95755db8af8a2ca5c19b"
#     },
#     "total_orders": 30,
#     "month": 10,
#     "store_name": "Off The Wall Sandwich Company"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "6544d1c8ebde7d15e2e7cf13"
#     },
#     "total_orders": 3,
#     "month": 10,
#     "store_name": "Pham's Kitchen"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "6669f42c230c24435c63b8cc"
#     },
#     "total_orders": 14,
#     "month": 10,
#     "store_name": "Phyu Thein"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "602d2d8263b7e5c183f269be"
#     },
#     "total_orders": 8,
#     "month": 10,
#     "store_name": "Pizza Plant Transit"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "62308c07e360923779cc8053"
#     },
#     "total_orders": 4,
#     "month": 10,
#     "store_name": "Rin Thai Bistro"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "618027873904904abf8f9ff7"
#     },
#     "total_orders": 8,
#     "month": 10,
#     "store_name": "Sports City Pizza Pub"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "6350035aaf0c66c48da29d93"
#     },
#     "total_orders": 4,
#     "month": 10,
#     "store_name": "The Grange Outpost"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "6579ee1925523d220c9959ca"
#     },
#     "total_orders": 21,
#     "month": 10,
#     "store_name": "The Ridge West Seneca"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "5fbcffb9e59b5518a91a66fe"
#     },
#     "total_orders": 1,
#     "month": 10,
#     "store_name": "Undergrounds Coffee House and Roastery "
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "61b8dad221a96859e2c43133"
#     },
#     "total_orders": 20,
#     "month": 10,
#     "store_name": "Voula's Greek Sweets"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "66841431230c24345b74adea"
#     },
#     "total_orders": 30,
#     "month": 10,
#     "store_name": "William's Kitchen"
#   },
#   {
#     "_id": {
#       "month": 10,
#       "store_id": "63e143fc0de38a94a99a7559"
#     },
#     "total_orders": 2,
#     "month": 10,
#     "store_name": "Winfield's Pub"
#   },
#   {
#     "_id": {
#       "month": 11,
#       "store_id": "5ffe033b5465ffa6c93cde70"
#     },
#     "total_orders": 7,
#     "month": 11,
#     "store_name": "Aguacates Mexican Bar & Grill | Elmwood"
#   },
#   {
#     "_id": {
#       "month": 11,
#       "store_id": "5fb5bf5934d2dc3679565cac"
#     },
#     "total_orders": 4,
#     "month": 11,
#     "store_name": "Ballyhoo"
#   },
#   {
#     "_id": {
#       "month": 11,
#       "store_id": "65f38e0c382f38abb6c3111e"
#     },
#     "total_orders": 1,
#     "month": 11,
#     "store_name": "Blue Eyed Baker"
#   },
#   {
#     "_id": {
#       "month": 11,
#       "store_id": "64fb74ecd347663f1e74be2c"
#     },
#     "total_orders": 10,
#     "month": 11,
#     "store_name": "Buffalo Deep Dish"
#   },
#   {
#     "_id": {
#       "month": 11,
#       "store_id": "5fb57c6e34d2dc77f8565a76"
#     },
#     "total_orders": 2,
#     "month": 11,
#     "store_name": "Butera's Craft Beer & Craft Pizza"
#   },
#   {
#     "_id": {
#       "month": 11,
#       "store_id": "5fc5707c0642fe105f7bf56d"
#     },
#     "total_orders": 3,
#     "month": 11,
#     "store_name": "Cafe 59"
#   },
#   {
#     "_id": {
#       "month": 11,
#       "store_id": "6650bae5230c248c894e1c92"
#     },
#     "total_orders": 6,
#     "month": 11,
#     "store_name": "Chef Bigwayne Jamaican Cuisine"
#   },
#   {
#     "_id": {
#       "month": 11,
#       "store_id": "66df28b51c49f819d9b36f74"
#     },
#     "total_orders": 4,
#     "month": 11,
#     "store_name": "Cristos Wood Fired Pizza & Pasta"
#   },
#   {
#     "_id": {
#       "month": 11,
#       "store_id": "5fa18d605c9bb56497ffb1ee"
#     },
#     "total_orders": 5,
#     "month": 11,
#     "store_name": "Fat Bob's Smokehouse"
#   },
#   {
#     "_id": {
#       "month": 11,
#       "store_id": "6384da2ef82eb777db9fd0f7"
#     },
#     "total_orders": 1,
#     "month": 11,
#     "store_name": "Giacobbi's Cucina Citta"
#   },
#   {
#     "_id": {
#       "month": 11,
#       "store_id": "5fda363171684a8075618c44"
#     },
#     "total_orders": 9,
#     "month": 11,
#     "store_name": "Glen Park Tavern "
#   },
#   {
#     "_id": {
#       "month": 11,
#       "store_id": "63cfefbd415cbf4fcae7a83a"
#     },
#     "total_orders": 1,
#     "month": 11,
#     "store_name": "Hanzlian's Homemade Sausage"
#   },
#   {
#     "_id": {
#       "month": 11,
#       "store_id": "60abca42c4354a1c628ca314"
#     },
#     "total_orders": 5,
#     "month": 11,
#     "store_name": "Lakeshore Cafe"
#   },
#   {
#     "_id": {
#       "month": 11,
#       "store_id": "63208ee5a7d7d40f864cde37"
#     },
#     "total_orders": 2,
#     "month": 11,
#     "store_name": "Lime House Sushi & Ramen | Hamburg"
#   },
#   {
#     "_id": {
#       "month": 11,
#       "store_id": "6669f3a1230c244ffc63b87b"
#     },
#     "total_orders": 1,
#     "month": 11,
#     "store_name": "Malkia and Co."
#   },
#   {
#     "_id": {
#       "month": 11,
#       "store_id": "64b6c970e2bd6e48353ec919"
#     },
#     "total_orders": 5,
#     "month": 11,
#     "store_name": "Mario's Bistro & Brews"
#   },
#   {
#     "_id": {
#       "month": 11,
#       "store_id": "6214f1ecb93c4f44247387a9"
#     },
#     "total_orders": 1,
#     "month": 11,
#     "store_name": "Milk & Tea"
#   },
#   {
#     "_id": {
#       "month": 11,
#       "store_id": "668d46be230c2480447b7772"
#     },
#     "total_orders": 8,
#     "month": 11,
#     "store_name": "O'Brien's West End"
#   },
#   {
#     "_id": {
#       "month": 11,
#       "store_id": "5fca95755db8af8a2ca5c19b"
#     },
#     "total_orders": 5,
#     "month": 11,
#     "store_name": "Off The Wall Sandwich Company"
#   },
#   {
#     "_id": {
#       "month": 11,
#       "store_id": "602d2d8263b7e5c183f269be"
#     },
#     "total_orders": 2,
#     "month": 11,
#     "store_name": "Pizza Plant Transit"
#   },
#   {
#     "_id": {
#       "month": 11,
#       "store_id": "62308c07e360923779cc8053"
#     },
#     "total_orders": 2,
#     "month": 11,
#     "store_name": "Rin Thai Bistro"
#   },
#   {
#     "_id": {
#       "month": 11,
#       "store_id": "618027873904904abf8f9ff7"
#     },
#     "total_orders": 3,
#     "month": 11,
#     "store_name": "Sports City Pizza Pub"
#   },
#   {
#     "_id": {
#       "month": 11,
#       "store_id": "6350035aaf0c66c48da29d93"
#     },
#     "total_orders": 2,
#     "month": 11,
#     "store_name": "The Grange Outpost"
#   },
#   {
#     "_id": {
#       "month": 11,
#       "store_id": "6579ee1925523d220c9959ca"
#     },
#     "total_orders": 3,
#     "month": 11,
#     "store_name": "The Ridge West Seneca"
#   },
#   {
#     "_id": {
#       "month": 11,
#       "store_id": "61b8dad221a96859e2c43133"
#     },
#     "total_orders": 6,
#     "month": 11,
#     "store_name": "Voula's Greek Sweets"
#   },
#   {
#     "_id": {
#       "month": 11,
#       "store_id": "66841431230c24345b74adea"
#     },
#     "total_orders": 4,
#     "month": 11,
#     "store_name": "William's Kitchen"
#   }
# ]

# %% [markdown]
# # least orders in past 6 months

# %%
#Current date and date 6 months ago
current_date = datetime.datetime.now()
six_months_ago = current_date - datetime.timedelta(days=180)

pipeline = [
    {
        "$match": {
            "createdAt": {"$gte": six_months_ago}
        }
    },
    {
        "$group": {
            "_id": "$store_id",
            "total_orders": {"$sum": 1}
        }
    },
    {
        "$lookup": {
            "from": "stores",
            "localField": "_id",
            "foreignField": "_id",
            "as": "store_details"
        }
    },
    {
        "$unwind": "$store_details"
    },
    {
        "$sort": {"total_orders": 1}  # Sort by total orders ascending to find the biggest declines
    },
    {
        "$limit": 5  # Limit to top 5 stores with the biggest declines
    },
    {
        "$project": {
            "store_name": "$store_details.name",
            "total_orders": 1
        }
    }
]

results = db.orders.aggregate(pipeline)
results_list = list(results)  # Convert cursor to list

# Print results as JSON
print(json.dumps(results_list, indent=2, default=str))
# Out:
# [
#   {
#     "_id": "63cfefbd415cbf4fcae7a83a",
#     "total_orders": 2,
#     "store_name": "Hanzlian's Homemade Sausage"
#   },
#   {
#     "_id": "66c74fe7bea643fc4b12caf0",
#     "total_orders": 2,
#     "store_name": "Two Nines Kitchen & Bar"
#   },
#   {
#     "_id": "671a52a2a81cf2b25e485b66",
#     "total_orders": 2,
#     "store_name": "Egyptian Bites"
#   },
#   {
#     "_id": "66854adc230c2416d875e4f1",
#     "total_orders": 3,
#     "store_name": "Oralia"
#   },
#   {
#     "_id": "6567471925523d16798c60ea",
#     "total_orders": 4,
#     "store_name": "La Verdad"
#   }
# ]

# %% [markdown]
# # Highest orders in the past 6 months

# %%
# Current date and date 6 months ago
current_date = datetime.datetime.now()
six_months_ago = current_date - datetime.timedelta(days=180)

pipeline = [
    {
        "$match": {
            "createdAt": {"$gte": six_months_ago}
        }
    },
    {
        "$group": {
            "_id": "$store_id",
            "total_orders": {"$sum": 1}
        }
    },
    {
        "$lookup": {
            "from": "stores",
            "localField": "_id",
            "foreignField": "_id",
            "as": "store_details"
        }
    },
    {
        "$unwind": "$store_details"
    },
    {
        "$sort": {"total_orders": -1}  # Sort by total orders descending to find the highest orders
    },
    {
        "$limit": 5  # Optionally limit to top 5 stores with the highest orders
    },
    {
        "$project": {
            "store_name": "$store_details.name",
            "total_orders": 1
        }
    }
]

results = db.orders.aggregate(pipeline)
results_list = list(results)  # Convert cursor to list

# Print results as JSON
print(json.dumps(results_list, indent=2, default=str))
# Out:
# [
#   {
#     "_id": "64fb74ecd347663f1e74be2c",
#     "total_orders": 315,
#     "store_name": "Buffalo Deep Dish"
#   },
#   {
#     "_id": "5fc5707c0642fe105f7bf56d",
#     "total_orders": 239,
#     "store_name": "Cafe 59"
#   },
#   {
#     "_id": "5fa18d605c9bb56497ffb1ee",
#     "total_orders": 165,
#     "store_name": "Fat Bob's Smokehouse"
#   },
#   {
#     "_id": "5fda363171684a8075618c44",
#     "total_orders": 158,
#     "store_name": "Glen Park Tavern "
#   },
#   {
#     "_id": "6422ecc5a7f10a43c4ff6baf",
#     "total_orders": 141,
#     "store_name": "Grass Fed Vegan Butcher Shop"
#   }
# ]

# %% [markdown]
# # Highest number of orders by user zip code  for past 6 months

# %%
pipeline = [
    {
        "$match": {
            "createdAt": {"$gte": datetime.datetime.now() - datetime.timedelta(days=180)},  # Last 6 months
            "zip_code": {"$exists": True, "$ne": ""}  # Ensures that the zip_code field exists and is not empty
        }
    },
    {
        "$group": {
            "_id": "$zip_code",
            "total_orders": {"$sum": 1}
        }
    },
    {
        "$sort": {"total_orders": -1}  # Sort by the number of orders descending
    },
    {
        "$limit": 5  # Limits the output to the top 5 entries
    },
    {
        "$project": {
            "zip_code": "$_id",
            "total_orders": 1
        }
    }
]

results = db.orders.aggregate(pipeline)
results_list = list(results)  # Convert cursor to list

# Print results as JSON
print(json.dumps(results_list, indent=2, default=str))  # Use default=str to handle datetime objects
# Out:
# [
#   {
#     "_id": null,
#     "total_orders": 1184,
#     "zip_code": null
#   },
#   {
#     "_id": "14075",
#     "total_orders": 156,
#     "zip_code": "14075"
#   },
#   {
#     "_id": "14213",
#     "total_orders": 139,
#     "zip_code": "14213"
#   },
#   {
#     "_id": "14222",
#     "total_orders": 112,
#     "zip_code": "14222"
#   },
#   {
#     "_id": "14216",
#     "total_orders": 79,
#     "zip_code": "14216"
#   }
# ]

# %% [markdown]
# # least orders in past 6 months wrt to user zip codes

# %%
pipeline = [
    {
        "$match": {
            "createdAt": {"$gte": datetime.datetime.now() - datetime.timedelta(days=180)},  # Last 6 months
            "zip_code": {"$exists": True, "$ne": ""}  # Ensures that the zip_code field exists and is not empty
        }
    },
    {
        "$group": {
            "_id": "$zip_code",
            "total_orders": {"$sum": 1}
        }
    },
    {
        "$sort": {"total_orders": 1}  # Sort by the number of orders ascending
    },
    {
        "$limit": 5  # Limits the output to the least 5 entries
    },
    {
        "$project": {
            "zip_code": "$_id",
            "total_orders": 1
        }
    }
]

results = db.orders.aggregate(pipeline)
results_list = list(results)  # Convert cursor to list

# Print results as JSON
print(json.dumps(results_list, indent=2, default=str))
# Out:
# [
#   {
#     "_id": "14425",
#     "total_orders": 1,
#     "zip_code": "14425"
#   },
#   {
#     "_id": "14608",
#     "total_orders": 1,
#     "zip_code": "14608"
#   },
#   {
#     "_id": "14612",
#     "total_orders": 1,
#     "zip_code": "14612"
#   },
#   {
#     "_id": "14580",
#     "total_orders": 1,
#     "zip_code": "14580"
#   },
#   {
#     "_id": "14068",
#     "total_orders": 1,
#     "zip_code": "14068"
#   }
# ]

# %% [markdown]
# # orders acc to zip of  restaurants

# %%
pipeline = [
    {
        "$lookup": {
            "from": "stores",  # Assuming the name of the collection where store details are stored
            "localField": "store_id",
            "foreignField": "_id",
            "as": "store_info"
        }
    },
    {
        "$unwind": "$store_info"
    },
    {
        "$match": {
            "createdAt": {"$gte": datetime.datetime.now() - datetime.timedelta(days=180)},  # Last 6 months
            "store_info.zip_code": {"$exists": True, "$ne": ""}  # Ensures the zip_code field exists and is not empty
        }
    },
    {
        "$group": {
            "_id": "$store_info.zip_code",
            "total_orders": {"$sum": 1}
        }
    },
    {
        "$sort": {"total_orders": -1}  # Sort by the number of orders descending
    },
    {
        "$project": {
            "zip_code": "$_id",
            "total_orders": 1
        }
    }
]

results = db.orders.aggregate(pipeline)
results_list = list(results)  # Convert cursor to list

# Print results as JSON
print(json.dumps(results_list, indent=2, default=str))  # Use default=str to handle datetime objects
# Out:
# [
#   {
#     "_id": "14202",
#     "total_orders": 556,
#     "zip_code": "14202"
#   },
#   {
#     "_id": "14204",
#     "total_orders": 414,
#     "zip_code": "14204"
#   },
#   {
#     "_id": "14213",
#     "total_orders": 339,
#     "zip_code": "14213"
#   },
#   {
#     "_id": "14127",
#     "total_orders": 238,
#     "zip_code": "14127"
#   },
#   {
#     "_id": "14221",
#     "total_orders": 207,
#     "zip_code": "14221"
#   },
#   {
#     "_id": "14222",
#     "total_orders": 145,
#     "zip_code": "14222"
#   },
#   {
#     "_id": "14620",
#     "total_orders": 141,
#     "zip_code": "14620"
#   },
#   {
#     "_id": "14075",
#     "total_orders": 140,
#     "zip_code": "14075"
#   },
#   {
#     "_id": "14219",
#     "total_orders": 137,
#     "zip_code": "14219"
#   },
#   {
#     "_id": "14607",
#     "total_orders": 125,
#     "zip_code": "14607"
#   },
#   {
#     "_id": "14224",
#     "total_orders": 105,
#     "zip_code": "14224"
#   },
#   {
#     "_id": "14052",
#     "total_orders": 55,
#     "zip_code": "14052"
#   },
#   {
#     "_id": "14226",
#     "total_orders": 48,
#     "zip_code": "14226"
#   },
#   {
#     "_id": "14216",
#     "total_orders": 29,
#     "zip_code": "14216"
#   },
#   {
#     "_id": "14218",
#     "total_orders": 25,
#     "zip_code": "14218"
#   },
#   {
#     "_id": "14624",
#     "total_orders": 15,
#     "zip_code": "14624"
#   },
#   {
#     "_id": "14227",
#     "total_orders": 13,
#     "zip_code": "14227"
#   },
#   {
#     "_id": "14210",
#     "total_orders": 11,
#     "zip_code": "14210"
#   },
#   {
#     "_id": "14203",
#     "total_orders": 8,
#     "zip_code": "14203"
#   },
#   {
#     "_id": "14206",
#     "total_orders": 4,
#     "zip_code": "14206"
#   },
#   {
#     "_id": "14225",
#     "total_orders": 2,
#     "zip_code": "14225"
#   }
# ]

# %% [markdown]
# # New users in last 3 months

# %%
three_months_ago = datetime.datetime.now() - datetime.timedelta(days=90)

pipeline = [
    {
        "$match": {
            "createdAt": {"$gte": three_months_ago}
        }
    },
    {
        "$group": {
            "_id": None,  # Grouping by None means counting all documents that match the previous stage
            "new_users_count": {"$sum": 1}
        }
    },
    {
        "$project": {
            "_id": 0,
            "new_users_count": 1
        }
    }
]

results = db.users.aggregate(pipeline)
results_list = list(results)  # Convert cursor to list

# Print results as JSON
print(json.dumps(results_list, indent=2, default=str))  # Use default=str to handle datetime objects
# Out:
# [
#   {
#     "new_users_count": 737
#   }
# ]

# %%
one_year_ago = datetime.datetime.now() - datetime.timedelta(days=365)

pipeline = [
    {
        "$match": {
            "createdAt": {"$gte": one_year_ago}
        }
    },
    {
        "$group": {
            "_id": {
                "year": {"$year": "$createdAt"},
                "month": {"$month": "$createdAt"}
            },
            "new_users_count": {"$sum": 1}
        }
    },
    {
        "$sort": {"_id.year": 1, "_id.month": 1}  # Sort by year and month
    },
    {
        "$project": {
            "year": "$_id.year",
            "month": "$_id.month",
            "new_users_count": 1,
            "_id": 0
        }
    }
]

results = db.users.aggregate(pipeline)
results_list = list(results)  # Convert cursor to list

# Print results as JSON
print(json.dumps(results_list, indent=2, default=str))
# Out:
# [
#   {
#     "new_users_count": 216,
#     "year": 2023,
#     "month": 11
#   },
#   {
#     "new_users_count": 303,
#     "year": 2023,
#     "month": 12
#   },
#   {
#     "new_users_count": 283,
#     "year": 2024,
#     "month": 1
#   },
#   {
#     "new_users_count": 326,
#     "year": 2024,
#     "month": 2
#   },
#   {
#     "new_users_count": 299,
#     "year": 2024,
#     "month": 3
#   },
#   {
#     "new_users_count": 214,
#     "year": 2024,
#     "month": 4
#   },
#   {
#     "new_users_count": 250,
#     "year": 2024,
#     "month": 5
#   },
#   {
#     "new_users_count": 253,
#     "year": 2024,
#     "month": 6
#   },
#   {
#     "new_users_count": 210,
#     "year": 2024,
#     "month": 7
#   },
#   {
#     "new_users_count": 239,
#     "year": 2024,
#     "month": 8
#   },
#   {
#     "new_users_count": 234,
#     "year": 2024,
#     "month": 9
#   },
#   {
#     "new_users_count": 261,
#     "year": 2024,
#     "month": 10
#   },
#   {
#     "new_users_count": 63,
#     "year": 2024,
#     "month": 11
#   }
# ]

# %% [markdown]
# # Average Order Value by User

# %%
pipeline = [
    {
        "$group": {
            "_id": "$user_id",
            "average_order_value": {"$avg": "$total_amount"}
        }
    },
    {
        "$sort": {"average_order_value": -1}
    }
]

results = db.orders.aggregate(pipeline)
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('659d7b886225e63b82132f0f'), 'average_order_value': 650.9}
# {'_id': ObjectId('65b8044b479e30c46d21dc3f'), 'average_order_value': 631.79}
# {'_id': ObjectId('65e9b039382f3846dfba9e1f'), 'average_order_value': 539.99}
# {'_id': ObjectId('66648b91230c24639d5f9a3e'), 'average_order_value': 517.21}
# {'_id': ObjectId('64b0051ae2bd6e6d013a3ea6'), 'average_order_value': 504.83}
# {'_id': ObjectId('655cd048ebde7dccfff93771'), 'average_order_value': 487.58500000000004}
# {'_id': ObjectId('62dff749a7d7d4899122d75f'), 'average_order_value': 484.365}
# {'_id': ObjectId('62e15518a7d7d4364923ac86'), 'average_order_value': 481.43}
# {'_id': ObjectId('66f44ec0819cc870c81b1245'), 'average_order_value': 448.2}
# {'_id': ObjectId('64fb49c3d347664cf3748aaa'), 'average_order_value': 418.39}
# {'_id': ObjectId('64524078d1bf7304bb6ec4ca'), 'average_order_value': 406.2875}
# {'_id': ObjectId('621e342a0d4469af2f19af70'), 'average_order_value': 396.22}
# {'_id': ObjectId('6601937dc2f3344339acbee8'), 'average_order_value': 395.62}
# {'_id': ObjectId('653298fad347660c0b9c8548'), 'average_order_value': 390.36}
# {'_id': ObjectId('66fff58548bb4e004bc6b7b9'), 'average_order_value': 388.35}
# {'_id': ObjectId('61faa7772d38567c1bce454c'), 'average_order_value': 384.59}
# {'_id': ObjectId('6519ef2cd34766498e8b5258'), 'average_order_value': 380.375}
# {'_id': ObjectId('67126964a81cf2434a40a1d4'), 'average_order_value': 379.26}
# {'_id': ObjectId('6341e758af0c668a53995172'), 'average_order_value': 375.04}
# {'_id': ObjectId('61ddd18521a968cb9fd3f6c3'), 'average_order_value': 371.53}
# {'_id': ObjectId('66a6bdb4eac02ef72fa1eeb9'), 'average_order_value': 367.37}
# {'_id': ObjectId('62b385f0a7d7d4323b05029d'), 'average_order_value': 362.15}
# {'_id': ObjectId('6255b799c7abd4fa2452e083'), 'average_order_value': 359.68}
# {'_id': ObjectId('620e74762b3da8ab54d48e59'), 'average_order_value': 359.57}
# {'_id': ObjectId('64a5d515e2bd6e26e933d307'), 'average_order_value': 357.15}
# {'_id': ObjectId('65023090d3476680fe79b65c'), 'average_order_value': 353.31}
# {'_id': ObjectId('6720f52fa81cf2fe744ee9ee'), 'average_order_value': 353.11}
# {'_id': ObjectId('65fde76bc2f334865aa86ca8'), 'average_order_value': 351.46}
# {'_id': ObjectId('64820456402e7b3d0626e442'), 'average_order_value': 345.45}
# {'_id': ObjectId('656e138e25523db8bc91593f'), 'average_order_value': 344.85}
# {'_id': ObjectId('66c0c3d8e59b69a6094efeb1'), 'average_order_value': 340.78}
# {'_id': ObjectId('65cfa689382f38ae0ca48b8b'), 'average_order_value': 335.55}
# {'_id': ObjectId('60eefa432691f21e402f63de'), 'average_order_value': 335.52}
# {'_id': ObjectId('66e584f06871509e9d5bbeba'), 'average_order_value': 330.13}
# {'_id': ObjectId('63208939a7d7d46ec24cdad3'), 'average_order_value': 328.76}
# {'_id': ObjectId('61c23b0321a968055dc83b46'), 'average_order_value': 325.63}
# {'_id': ObjectId('64482bcb762ccee5621e502d'), 'average_order_value': 319.7}
# {'_id': ObjectId('60d5db60640d3c0cc85cdc84'), 'average_order_value': 313.0}
# {'_id': ObjectId('66f1bb43819cc8941c185427'), 'average_order_value': 309.22}
# {'_id': ObjectId('639e0647f82eb723a0a05007'), 'average_order_value': 308.24}
# {'_id': ObjectId('61e1956621a96858fbd5dae3'), 'average_order_value': 305.4}
# {'_id': ObjectId('6695c3e5eac02e342f93cba5'), 'average_order_value': 304.44}
# {'_id': ObjectId('66d1e5f711e3b4299a2fbb09'), 'average_order_value': 302.39}
# {'_id': ObjectId('61cb8f6721a96849f6cc1c3d'), 'average_order_value': 302.19}
# {'_id': ObjectId('6585b2ebeaca1887d5228348'), 'average_order_value': 300.75}
# {'_id': ObjectId('647a43c3402e7bd497214fd6'), 'average_order_value': 297.04}
# {'_id': ObjectId('6258151dc7abd42b52543aee'), 'average_order_value': 293.77}
# {'_id': ObjectId('61b10da08dfef81205febe83'), 'average_order_value': 293.0}
# {'_id': ObjectId('64284383a7f10af40bff873d'), 'average_order_value': 291.06}
# {'_id': ObjectId('6227c1b5e360924434c6f831'), 'average_order_value': 285.5040740740741}
# {'_id': ObjectId('664509a746278dc3183e8511'), 'average_order_value': 284.89}
# {'_id': ObjectId('658d98dbeaca18edad26fdb8'), 'average_order_value': 284.04}
# {'_id': ObjectId('652ac1f3d3476648ab96de54'), 'average_order_value': 284.01}
# {'_id': ObjectId('602a8dc384f435468a742d83'), 'average_order_value': 283.32375}
# {'_id': ObjectId('6464e86d402e7b5fd0115466'), 'average_order_value': 276.69}
# {'_id': ObjectId('671d45b4a81cf2d7bc4bc3e3'), 'average_order_value': 275.21}
# {'_id': ObjectId('64d3f31be2bd6ed372537f6d'), 'average_order_value': 272.37}
# {'_id': ObjectId('6207fe632b3da87f91d1a116'), 'average_order_value': 270.79}
# {'_id': ObjectId('6233fe0ebd3f1215ad83b6eb'), 'average_order_value': 269.67999999999995}
# {'_id': ObjectId('66c8c224bea64361c914d061'), 'average_order_value': 269.25}
# {'_id': ObjectId('6272d83ec7abd4698365510f'), 'average_order_value': 268.95}
# {'_id': ObjectId('63122f78a7d7d4bccf433e25'), 'average_order_value': 264.91}
# {'_id': ObjectId('648b1c52fb19f28778da15cc'), 'average_order_value': 262.78}
# {'_id': ObjectId('669049a6eac02e77028f1f0f'), 'average_order_value': 261.57}
# {'_id': ObjectId('62b76c8fa7d7d44d0b07c5cd'), 'average_order_value': 258.69}
# {'_id': ObjectId('642467b3a7f10a5a14ff725f'), 'average_order_value': 257.68}
# {'_id': ObjectId('62e1339aa7d7d4c7c42397b9'), 'average_order_value': 254.41}
# {'_id': ObjectId('631b8c4ca7d7d49fbc49c823'), 'average_order_value': 252.32}
# {'_id': ObjectId('67128fd4a81cf2169e40e2f1'), 'average_order_value': 252.18}
# {'_id': ObjectId('63e3bac70de38a4eb79a863f'), 'average_order_value': 251.05}
# {'_id': ObjectId('65c27275382f3808eb9a0146'), 'average_order_value': 250.1}
# {'_id': ObjectId('641c4beba7f10a18fcff4a42'), 'average_order_value': 249.95}
# {'_id': ObjectId('644ab8c7762cce8129209504'), 'average_order_value': 249.27}
# {'_id': ObjectId('638e5c64f82eb7638f9ffe0d'), 'average_order_value': 248.52}
# {'_id': ObjectId('62715f53c7abd40dec646b77'), 'average_order_value': 248.22000000000003}
# {'_id': ObjectId('65fb0359c2f33400a1a498d0'), 'average_order_value': 247.12}
# {'_id': ObjectId('662fe98aa6eb18153b5994c1'), 'average_order_value': 247.03}
# {'_id': ObjectId('65399c8fd347666f72a17903'), 'average_order_value': 246.05}
# {'_id': ObjectId('667ac0a6230c24749b6eb55a'), 'average_order_value': 244.62}
# {'_id': ObjectId('60a40c9a4575ff1cffd07134'), 'average_order_value': 243.37333333333336}
# {'_id': ObjectId('66dba1641c49f84987afff16'), 'average_order_value': 243.32}
# {'_id': ObjectId('625ebe7ac7abd4711f5892bf'), 'average_order_value': 240.91}
# {'_id': ObjectId('64e8e78de2bd6e2d5063c2e5'), 'average_order_value': 240.32999999999998}
# {'_id': ObjectId('651f1770d347662baa8e6c1b'), 'average_order_value': 240.12}
# {'_id': ObjectId('666c76f5230c24965d656579'), 'average_order_value': 239.47}
# {'_id': ObjectId('65a1bcb06225e64c2e164c70'), 'average_order_value': 239.25}
# {'_id': ObjectId('64cecc67e2bd6e9f60503ae0'), 'average_order_value': 239.04}
# {'_id': ObjectId('6526c0a3d3476681e793c4c8'), 'average_order_value': 238.78}
# {'_id': ObjectId('660ea43f2d794a3cb637aae4'), 'average_order_value': 238.09}
# {'_id': ObjectId('6679e0e3230c2416da6e75f8'), 'average_order_value': 237.49}
# {'_id': ObjectId('64de3e1fe2bd6e3cda5b425c'), 'average_order_value': 236.205}
# {'_id': ObjectId('666b0e45230c2461b2643f68'), 'average_order_value': 234.24}
# {'_id': ObjectId('62070a9b2b3da86630d11ba9'), 'average_order_value': 233.69}
# {'_id': ObjectId('65778de525523d372b982705'), 'average_order_value': 233.47}
# {'_id': ObjectId('636d1d634e0e14462c569085'), 'average_order_value': 232.3}
# {'_id': ObjectId('655777d7ebde7d46cff4f72b'), 'average_order_value': 232.12}
# {'_id': ObjectId('6481fc01402e7b5bef26d761'), 'average_order_value': 231.99}
# {'_id': ObjectId('664cc76d46278d84c8453e6e'), 'average_order_value': 230.64}
# {'_id': ObjectId('6149091a382e63a2ae6c46c2'), 'average_order_value': 230.05}
# {'_id': ObjectId('6303b247a7d7d420c63a585b'), 'average_order_value': 228.05}
# {'_id': ObjectId('6346e787af0c660d059ca569'), 'average_order_value': 226.51}
# {'_id': ObjectId('62d419eea7d7d4910a1b9422'), 'average_order_value': 225.54}
# {'_id': ObjectId('63efd95f0de38aeafb9ad246'), 'average_order_value': 225.015}
# {'_id': ObjectId('66fecdd29691337949f565c8'), 'average_order_value': 222.79}
# {'_id': ObjectId('6723a6f0a81cf2a7925215a1'), 'average_order_value': 221.9}
# {'_id': ObjectId('620e5f752b3da85974d48356'), 'average_order_value': 221.67}
# {'_id': ObjectId('62d17bdda7d7d49b4219a266'), 'average_order_value': 221.5566666666667}
# {'_id': ObjectId('642c47f2a7f10a9357ffa12b'), 'average_order_value': 221.38}
# {'_id': ObjectId('63e2ef330de38acd689a856f'), 'average_order_value': 220.1}
# {'_id': ObjectId('5fc63511e59b5549a31aaec1'), 'average_order_value': 219.99943749999994}
# {'_id': ObjectId('63766956f82eb7038c9f4db7'), 'average_order_value': 218.66}
# {'_id': ObjectId('64b1ca13e2bd6e04043baaca'), 'average_order_value': 218.48}
# {'_id': ObjectId('621eb3a50d44697c3119f7fc'), 'average_order_value': 217.77}
# {'_id': ObjectId('61def2e421a968d2fcd483f2'), 'average_order_value': 217.49}
# {'_id': ObjectId('66437f4846278dc0e43cd043'), 'average_order_value': 217.255}
# {'_id': ObjectId('648ce5fdfb19f22f6fdbc8cc'), 'average_order_value': 217.07}
# {'_id': ObjectId('649f0c58e2bd6e61e92fad81'), 'average_order_value': 216.375}
# {'_id': ObjectId('656a4fbf25523d83798ed281'), 'average_order_value': 216.37}
# {'_id': ObjectId('607acbf0ec3ebf4d692957d6'), 'average_order_value': 214.62}
# {'_id': ObjectId('60577ef81427b258aa069517'), 'average_order_value': 214.20499999999998}
# {'_id': ObjectId('6419c216a7f10a6b4fff3c52'), 'average_order_value': 213.98}
# {'_id': ObjectId('66a019abeac02e31a79bcc55'), 'average_order_value': 213.96}
# {'_id': ObjectId('6542b083ebde7d21e9e5f3d2'), 'average_order_value': 213.26}
# {'_id': ObjectId('65cd3e47382f38e9c5a208b3'), 'average_order_value': 212.54}
# {'_id': ObjectId('66019e68c2f33409ebacde3c'), 'average_order_value': 212.53}
# {'_id': ObjectId('64d7b34ae2bd6e6e17568e2b'), 'average_order_value': 212.11}
# {'_id': ObjectId('63506981af0c6633d9a2ddeb'), 'average_order_value': 210.63}
# {'_id': ObjectId('61c49ec821a968a879c95f4b'), 'average_order_value': 210.61}
# {'_id': ObjectId('60f04f772691f288b92f7496'), 'average_order_value': 210.54}
# {'_id': ObjectId('640a0c520c1fa3e4604b5650'), 'average_order_value': 209.18}
# {'_id': ObjectId('6241d825bd3f1244748c92b7'), 'average_order_value': 208.78}
# {'_id': ObjectId('620a9e312b3da87d23d2e8c5'), 'average_order_value': 207.27}
# {'_id': ObjectId('620ee4f62b3da8290cd4dd29'), 'average_order_value': 205.93}
# {'_id': ObjectId('6717c088a81cf2191d46140b'), 'average_order_value': 205.9}
# {'_id': ObjectId('62e197cfa7d7d463d823e303'), 'average_order_value': 202.53}
# {'_id': ObjectId('658f85f9eaca182fec28fb99'), 'average_order_value': 202.27}
# {'_id': ObjectId('646bac45402e7b5c351713ee'), 'average_order_value': 202.21}
# {'_id': ObjectId('5fda8e9371684ab7c0618d38'), 'average_order_value': 202.12}
# {'_id': ObjectId('65fb3714c2f33482a9a50735'), 'average_order_value': 201.99}
# {'_id': ObjectId('6262c2a1c7abd47f975b3aa2'), 'average_order_value': 200.77}
# {'_id': ObjectId('6245c2b3bd3f1275ba8eff37'), 'average_order_value': 200.74}
# {'_id': ObjectId('67180a53a81cf26bec467264'), 'average_order_value': 200.63}
# {'_id': ObjectId('629f6838a7d7d47729f6f507'), 'average_order_value': 200.44}
# {'_id': ObjectId('60392d9ca246a749d008bd09'), 'average_order_value': 200.25}
# {'_id': ObjectId('621befe3b93c4f596b778ca1'), 'average_order_value': 200.23}
# {'_id': ObjectId('66699dcc230c247e6c635502'), 'average_order_value': 199.48}
# {'_id': ObjectId('622b7bb5e36092f3b9c97682'), 'average_order_value': 199.46}
# {'_id': ObjectId('6425b650a7f10a8308ff7851'), 'average_order_value': 199.28}
# {'_id': ObjectId('622a0bbae360920cdac862c2'), 'average_order_value': 198.45}
# {'_id': ObjectId('63458729af0c66f5269b9ad8'), 'average_order_value': 198.175}
# {'_id': ObjectId('609d3d0c4575ff6b90d044b3'), 'average_order_value': 196.42}
# {'_id': ObjectId('61b3bbda8dfef8c17effe519'), 'average_order_value': 196.2}
# {'_id': ObjectId('637a6b3ef82eb7572a9f664f'), 'average_order_value': 195.33}
# {'_id': ObjectId('62e94c37a7d7d402b328e1fb'), 'average_order_value': 195.27}
# {'_id': ObjectId('60970d1f7bc8216ac5e8452c'), 'average_order_value': 194.95}
# {'_id': ObjectId('65b9234e479e30d3bf2256d3'), 'average_order_value': 194.5}
# {'_id': ObjectId('66cdf9d6bea643ecef198a56'), 'average_order_value': 194.475}
# {'_id': ObjectId('65b6a617479e3084c320f424'), 'average_order_value': 193.44}
# {'_id': ObjectId('65f1b147382f3851e8c12667'), 'average_order_value': 193.33}
# {'_id': ObjectId('61059a6a2691f2b55e301225'), 'average_order_value': 192.95}
# {'_id': ObjectId('5fccf4e9e6ed0265bea5d5bf'), 'average_order_value': 192.92}
# {'_id': ObjectId('6560f08c25523d3b4d88c41f'), 'average_order_value': 192.44}
# {'_id': ObjectId('65ee15c4382f3857fbbf1081'), 'average_order_value': 192.0}
# {'_id': ObjectId('60ef04e32691f2c0cd2f681a'), 'average_order_value': 191.86}
# {'_id': ObjectId('63acbd5b415cbf7467e693a4'), 'average_order_value': 191.44}
# {'_id': ObjectId('61957d2e9e5c7b1e9cc58ec2'), 'average_order_value': 191.28}
# {'_id': ObjectId('64230132a7f10a563fff6bf9'), 'average_order_value': 190.81}
# {'_id': ObjectId('6460e2a7402e7bbffb0ede6d'), 'average_order_value': 190.31}
# {'_id': ObjectId('66dc87b41c49f89e0ab0cd01'), 'average_order_value': 190.14}
# {'_id': ObjectId('64382260a7f10ac8a7fffb70'), 'average_order_value': 189.94}
# {'_id': ObjectId('5fc99a645819fdc7d7b3458b'), 'average_order_value': 189.608125}
# {'_id': ObjectId('61cb302d21a968211dcbdc7b'), 'average_order_value': 189.49}
# {'_id': ObjectId('669970aceac02e6cc896a7fd'), 'average_order_value': 189.19}
# {'_id': ObjectId('665b5cec230c24492f56d819'), 'average_order_value': 188.63}
# {'_id': ObjectId('6043db9a13b4c339e475a2fb'), 'average_order_value': 188.3483125}
# {'_id': ObjectId('621e5e7b0d446922fb19c3f2'), 'average_order_value': 188.34}
# {'_id': ObjectId('6047a6b513b4c308d275c0a4'), 'average_order_value': 188.19156250000003}
# {'_id': ObjectId('63c5b6bb415cbf61d2e76ab3'), 'average_order_value': 188.1}
# {'_id': ObjectId('63fe583f0de38abb5e9b27fc'), 'average_order_value': 187.74}
# {'_id': ObjectId('66043c9a2d794a374e2ccfc9'), 'average_order_value': 186.42}
# {'_id': ObjectId('63caa1fd415cbf14fde78696'), 'average_order_value': 186.20000000000002}
# {'_id': ObjectId('63445e48af0c6618659adc20'), 'average_order_value': 185.97}
# {'_id': ObjectId('62582113c7abd47ad854414a'), 'average_order_value': 185.79}
# {'_id': ObjectId('62fd7f83a7d7d46a4f369b8e'), 'average_order_value': 185.03}
# {'_id': ObjectId('668eac93eac02e5f868d5d79'), 'average_order_value': 184.43}
# {'_id': ObjectId('606f1622ec3ebf737828f8ec'), 'average_order_value': 184.25666666666666}
# {'_id': ObjectId('625766d2c7abd4f22653e636'), 'average_order_value': 183.86}
# {'_id': ObjectId('628cc9c9dcd97566d791d4ef'), 'average_order_value': 183.65}
# {'_id': ObjectId('62ed9c1ca7d7d4dfff2c1654'), 'average_order_value': 183.53}
# {'_id': ObjectId('60464ad713b4c30af575b0f5'), 'average_order_value': 183.29312500000003}
# {'_id': ObjectId('65de0635382f38cbb5b0cf9d'), 'average_order_value': 183.26500000000001}
# {'_id': ObjectId('624f05c7e02d970548984bdb'), 'average_order_value': 183.1}
# {'_id': ObjectId('6468f4fb402e7b4c7514d63b'), 'average_order_value': 182.82}
# {'_id': ObjectId('632cadaeaf0c6686238ad3dc'), 'average_order_value': 182.64}
# {'_id': ObjectId('661324a92d794a4dfa3d773b'), 'average_order_value': 182.59}
# {'_id': ObjectId('6467f496402e7bd7c31406cd'), 'average_order_value': 181.35500000000002}
# {'_id': ObjectId('665cf0dc230c24a72f58fee3'), 'average_order_value': 181.19}
# {'_id': ObjectId('62617bcbc7abd477b75a3c9a'), 'average_order_value': 181.08}
# {'_id': ObjectId('6220ea9c0d44694d5c1b13a2'), 'average_order_value': 180.51999999999998}
# {'_id': ObjectId('632b2be2af0c663efb89bc3f'), 'average_order_value': 180.355}
# {'_id': ObjectId('649473139d042c689f0d139a'), 'average_order_value': 180.17}
# {'_id': ObjectId('6031830463b7e5ab2ff2b352'), 'average_order_value': 179.96124999999998}
# {'_id': ObjectId('62ac95a6a7d7d42e02002d38'), 'average_order_value': 179.77}
# {'_id': ObjectId('63c0a25a415cbf89f2e74f40'), 'average_order_value': 178.55}
# {'_id': ObjectId('63ade511415cbf3fb8e69a25'), 'average_order_value': 177.74}
# {'_id': ObjectId('65a166656225e62dfc15d1c5'), 'average_order_value': 177.44}
# {'_id': ObjectId('6481de8b402e7b19fb26b8b0'), 'average_order_value': 177.37}
# {'_id': ObjectId('604e87e013b4c327ca7647d4'), 'average_order_value': 177.04000000000002}
# {'_id': ObjectId('6404c9ad0de38a78bf9b5c06'), 'average_order_value': 176.77}
# {'_id': ObjectId('65b1949e45b19fd45e09c46e'), 'average_order_value': 176.01}
# {'_id': ObjectId('6179e99e382e63149f78a2e5'), 'average_order_value': 176.0}
# {'_id': ObjectId('6371300b4e0e14d6f456b328'), 'average_order_value': 175.65}
# {'_id': ObjectId('6143916d382e63e7c46b38e9'), 'average_order_value': 175.37}
# {'_id': ObjectId('663fdb2446278d15c239a20c'), 'average_order_value': 174.91}
# {'_id': ObjectId('5fd3e368cda0f73f7ec178eb'), 'average_order_value': 174.907}
# {'_id': ObjectId('6410866d2887ee42fb77cb63'), 'average_order_value': 174.56}
# {'_id': ObjectId('617186b2382e635feb766cbd'), 'average_order_value': 173.99}
# {'_id': ObjectId('5f9b4b935c9bb5735effafbf'), 'average_order_value': 173.91}
# {'_id': ObjectId('613cb79788b11e4156af5b13'), 'average_order_value': 173.5}
# {'_id': ObjectId('6253174ee02d975c539b1265'), 'average_order_value': 173.3}
# {'_id': ObjectId('61e9e69621a9687857d9d48d'), 'average_order_value': 172.82}
# {'_id': ObjectId('610d8d20bd43116d9391cd3d'), 'average_order_value': 172.26}
# {'_id': ObjectId('63cac96c415cbfc78fe78765'), 'average_order_value': 171.485}
# {'_id': ObjectId('63093b38a7d7d41d653d8d51'), 'average_order_value': 169.89}
# {'_id': ObjectId('660461ad2d794a7e202d2371'), 'average_order_value': 169.72}
# {'_id': ObjectId('655794b6ebde7ddcb1f50cab'), 'average_order_value': 169.7}
# {'_id': ObjectId('616975b4382e632262747286'), 'average_order_value': 169.32}
# {'_id': ObjectId('65e25fd3382f38f6a1b549a5'), 'average_order_value': 168.57}
# {'_id': ObjectId('66784618230c2427e76d4100'), 'average_order_value': 168.16}
# {'_id': ObjectId('614b4052382e632ce56cc21b'), 'average_order_value': 168.08}
# {'_id': ObjectId('61e9845221a9680160d996db'), 'average_order_value': 167.905}
# {'_id': ObjectId('60858a6573cd0b52fdadf82a'), 'average_order_value': 167.85}
# {'_id': ObjectId('657e240825523d788e9d0939'), 'average_order_value': 167.6}
# {'_id': ObjectId('6351848a702f2b6364070447'), 'average_order_value': 167.51}
# {'_id': ObjectId('64907923fb19f21053ddf8f5'), 'average_order_value': 167.47}
# {'_id': ObjectId('62912b70dcd9750ec494849f'), 'average_order_value': 166.85}
# {'_id': ObjectId('64e4fea9e2bd6e167f60951f'), 'average_order_value': 166.8}
# {'_id': ObjectId('61ed83d521a9687b6bdbd6ef'), 'average_order_value': 166.475}
# {'_id': ObjectId('60d4dd65640d3cb7f55cd01e'), 'average_order_value': 166.07}
# {'_id': ObjectId('631d1cb4a7d7d4b9c64ae9d0'), 'average_order_value': 165.99}
# {'_id': ObjectId('63e117e70de38aa9959a750a'), 'average_order_value': 165.96}
# {'_id': ObjectId('63dfef960de38ac8859a6ac7'), 'average_order_value': 165.9}
# {'_id': ObjectId('661c4f3e2d794afeef476dd2'), 'average_order_value': 165.62}
# {'_id': ObjectId('6297bd70b672a8749b1338e6'), 'average_order_value': 165.375}
# {'_id': ObjectId('64b958c5e2bd6efcb940a8e4'), 'average_order_value': 165.16}
# {'_id': ObjectId('6246f586bd3f120c7a8fc871'), 'average_order_value': 164.91}
# {'_id': ObjectId('603972eaa246a76ba708bf47'), 'average_order_value': 164.85172500000002}
# {'_id': ObjectId('612ff23f4867e94644174948'), 'average_order_value': 164.84}
# {'_id': ObjectId('618699889e5c7b1d29c10d8d'), 'average_order_value': 164.29}
# {'_id': ObjectId('63e9274e0de38a7fb49aa863'), 'average_order_value': 164.23}
# {'_id': ObjectId('6402addc0de38a07569b4ebf'), 'average_order_value': 164.23}
# {'_id': ObjectId('625626f4c7abd4dcdb532f7a'), 'average_order_value': 163.48}
# {'_id': ObjectId('6000aaedcb2a807675f0cd0e'), 'average_order_value': 163.39538125}
# {'_id': ObjectId('5fff7e9dcb2a80265ef0c1e8'), 'average_order_value': 163.33666666666667}
# {'_id': ObjectId('60e86a29640d3cfa745d8409'), 'average_order_value': 163.12}
# {'_id': ObjectId('605661481427b25a0c06868d'), 'average_order_value': 163.02}
# {'_id': ObjectId('61ec8a4e21a9686a39db58c2'), 'average_order_value': 162.69}
# {'_id': ObjectId('622231350d44696df31bf263'), 'average_order_value': 162.68333333333334}
# {'_id': ObjectId('629a8777a7d7d463a8f40f44'), 'average_order_value': 162.37}
# {'_id': ObjectId('6313d2e0a7d7d43c8d445410'), 'average_order_value': 161.89}
# {'_id': ObjectId('6705aca2a81cf2f76f346d56'), 'average_order_value': 161.74}
# {'_id': ObjectId('604f7d9813b4c37d1b764d7b'), 'average_order_value': 161.74}
# {'_id': ObjectId('64f9c56ce2bd6e75186e949c'), 'average_order_value': 161.17}
# {'_id': ObjectId('6225f59e0d4469d78e1e2dc7'), 'average_order_value': 161.15}
# {'_id': ObjectId('62b86dd5a7d7d45e64086662'), 'average_order_value': 160.55}
# {'_id': ObjectId('63d45f72415cbf38e8e7c5dd'), 'average_order_value': 160.43}
# {'_id': ObjectId('62adf6b6a7d7d43104014342'), 'average_order_value': 160.25}
# {'_id': ObjectId('66dcc38f1c49f81ae1b12741'), 'average_order_value': 160.13}
# {'_id': ObjectId('6084a94873cd0b0ed6adf417'), 'average_order_value': 160.06}
# {'_id': ObjectId('5fe3896a033f0de7d10f9b22'), 'average_order_value': 159.601675}
# {'_id': ObjectId('652471bcd3476649d0925013'), 'average_order_value': 159.33}
# {'_id': ObjectId('6197b9e724c69a18e574924a'), 'average_order_value': 159.18}
# {'_id': ObjectId('609c8e5a4575ff06abd0441d'), 'average_order_value': 159.12}
# {'_id': ObjectId('66bb5833e59b6932b8494f00'), 'average_order_value': 159.05}
# {'_id': ObjectId('66902c8deac02e85448ef8cf'), 'average_order_value': 158.85}
# {'_id': ObjectId('65957dcceaca18271b2c8ad7'), 'average_order_value': 158.82}
# {'_id': ObjectId('66716a88230c24fae368e831'), 'average_order_value': 158.8}
# {'_id': ObjectId('60f18b972691f265632f7ea8'), 'average_order_value': 158.52}
# {'_id': ObjectId('607ca21eec3ebf7702296315'), 'average_order_value': 158.47}
# {'_id': ObjectId('62f68850a7d7d4197731fe30'), 'average_order_value': 158.36}
# {'_id': ObjectId('6116d07748521b8f84e7c42a'), 'average_order_value': 157.98}
# {'_id': ObjectId('62d184e7a7d7d4134c19a8c1'), 'average_order_value': 157.59}
# {'_id': ObjectId('60c506dc03b5ac3e69323884'), 'average_order_value': 157.42}
# {'_id': ObjectId('600b4525f6990216650ed80a'), 'average_order_value': 157.39451250000002}
# {'_id': ObjectId('63f8fbd20de38abdf89afee9'), 'average_order_value': 157.27}
# {'_id': ObjectId('6340a942af0c6673bc987ca7'), 'average_order_value': 157.215}
# {'_id': ObjectId('66cdf4a3bea6432732197921'), 'average_order_value': 157.12}
# {'_id': ObjectId('65f46619382f38090dc3a289'), 'average_order_value': 156.86}
# {'_id': ObjectId('62d1da29a7d7d4590a19eb7a'), 'average_order_value': 156.82636363636365}
# {'_id': ObjectId('62fd1bd6a7d7d4a52f3643fe'), 'average_order_value': 156.66}
# {'_id': ObjectId('64d64f75e2bd6e9eb255543b'), 'average_order_value': 156.62}
# {'_id': ObjectId('60f88d422691f299442fcb0c'), 'average_order_value': 156.51}
# {'_id': ObjectId('662401a73d9bc505980126c6'), 'average_order_value': 156.41}
# {'_id': ObjectId('657e19a025523dfe4a9cf422'), 'average_order_value': 156.39}
# {'_id': ObjectId('61c3543421a9687619c899cf'), 'average_order_value': 156.34}
# {'_id': ObjectId('5fe90a4a033f0d904b0fc8b8'), 'average_order_value': 155.64675}
# {'_id': ObjectId('635a7e984e0e14a757563382'), 'average_order_value': 155.55}
# {'_id': ObjectId('620975e12b3da8149dd27d41'), 'average_order_value': 155.08}
# {'_id': ObjectId('6055181d1427b27351067dd1'), 'average_order_value': 155.01}
# {'_id': ObjectId('6580b33325523d5ea89ebb9f'), 'average_order_value': 154.78}
# {'_id': ObjectId('600cafc2f69902fcb30f085a'), 'average_order_value': 154.7443125}
# {'_id': ObjectId('62164239b93c4f0bc5742835'), 'average_order_value': 154.73}
# {'_id': ObjectId('65259d89d347666480930e76'), 'average_order_value': 154.325}
# {'_id': ObjectId('60206608f699020b0910537b'), 'average_order_value': 154.3030625}
# {'_id': ObjectId('6241fd98bd3f12134e8cab3e'), 'average_order_value': 154.17}
# {'_id': ObjectId('6065c8e9ec3ebfd7df287b26'), 'average_order_value': 153.95}
# {'_id': ObjectId('5fd4050f32d995a2629d34b3'), 'average_order_value': 153.50394999999997}
# {'_id': ObjectId('5fca9ed25db8af72aba5c1c3'), 'average_order_value': 153.36143}
# {'_id': ObjectId('610417a62691f28e1c300de8'), 'average_order_value': 152.93}
# {'_id': ObjectId('6009ee13f6990216000ecb4f'), 'average_order_value': 152.89}
# {'_id': ObjectId('6292c413dcd975c26c95cc44'), 'average_order_value': 152.83}
# {'_id': ObjectId('6675e8b4230c24a38b6b96a9'), 'average_order_value': 152.75}
# {'_id': ObjectId('63ebb1460de38a20fb9ab578'), 'average_order_value': 152.185}
# {'_id': ObjectId('622297060d446963a11c4edc'), 'average_order_value': 151.66333333333333}
# {'_id': ObjectId('66c62180bea64322b31144a2'), 'average_order_value': 151.66}
# {'_id': ObjectId('62a90307a7d7d46ef0fd4792'), 'average_order_value': 150.51}
# {'_id': ObjectId('65032ab6d3476630317a55bb'), 'average_order_value': 150.37}
# {'_id': ObjectId('666f200d230c240c9a677f30'), 'average_order_value': 149.78}
# {'_id': ObjectId('61635e01382e63ef09731260'), 'average_order_value': 149.45}
# {'_id': ObjectId('61f588db21a968e88fdfba94'), 'average_order_value': 149.37}
# {'_id': ObjectId('5ff0dbe04b9fb13ccd77b4e6'), 'average_order_value': 149.3581875}
# {'_id': ObjectId('6214f6b3b93c4f5f1f7389bf'), 'average_order_value': 149.0}
# {'_id': ObjectId('6317c38aa7d7d403094704ce'), 'average_order_value': 148.65}
# {'_id': ObjectId('632098b4a7d7d4c6974ce4ba'), 'average_order_value': 148.57}
# {'_id': ObjectId('62f92e7ea7d7d42f2e33e0a4'), 'average_order_value': 148.37}
# {'_id': ObjectId('662822e53d9bc52e5e03c22f'), 'average_order_value': 148.36}
# {'_id': ObjectId('61aa53678dfef828b8fbc6ba'), 'average_order_value': 148.01}
# {'_id': ObjectId('5fdd408d9cb7ed47c73c5b01'), 'average_order_value': 147.9103225}
# {'_id': ObjectId('64a9e4bde2bd6e22b4367b6a'), 'average_order_value': 147.865}
# {'_id': ObjectId('627bb143c7abd4b2526a6314'), 'average_order_value': 147.8}
# {'_id': ObjectId('6102f66a2691f2d903300c28'), 'average_order_value': 147.72}
# {'_id': ObjectId('653d70fcebde7d5727e26fe8'), 'average_order_value': 147.61}
# {'_id': ObjectId('602415d162dd361cf8a26e4f'), 'average_order_value': 147.454}
# {'_id': ObjectId('66589e68230c24333753952d'), 'average_order_value': 147.43}
# {'_id': ObjectId('64773fc0402e7b13e81ecf90'), 'average_order_value': 147.25}
# {'_id': ObjectId('63ff868e0de38a5c5a9b2b47'), 'average_order_value': 147.115}
# {'_id': ObjectId('654d5dbfebde7da5bdedfb34'), 'average_order_value': 147.07}
# {'_id': ObjectId('62febdd2a7d7d47406376977'), 'average_order_value': 147.01799999999997}
# {'_id': ObjectId('644a7da2762cce7ad22042e8'), 'average_order_value': 146.97}
# {'_id': ObjectId('66847ab6230c24144d753ca9'), 'average_order_value': 146.94}
# {'_id': ObjectId('5fc53edc0642feeb877bf53b'), 'average_order_value': 146.83}
# {'_id': ObjectId('5fc906935db8af8065a5ae8e'), 'average_order_value': 146.56}
# {'_id': ObjectId('634c7c01af0c666b09a0b45c'), 'average_order_value': 146.38}
# {'_id': ObjectId('66c24684e59b6910325098b2'), 'average_order_value': 145.69}
# {'_id': ObjectId('63c3246d415cbf2ed1e75b8f'), 'average_order_value': 145.68}
# {'_id': ObjectId('64bd8d35e2bd6ec16d43fd90'), 'average_order_value': 145.34}
# {'_id': ObjectId('635d37954e0e14106d5643cf'), 'average_order_value': 144.74}
# {'_id': ObjectId('63951920f82eb7f4b8a0247a'), 'average_order_value': 144.65}
# {'_id': ObjectId('66465ee046278d2b313fd13a'), 'average_order_value': 144.51}
# {'_id': ObjectId('5ff8ebcc7dfa5d85b31499b4'), 'average_order_value': 144.46}
# {'_id': ObjectId('641339a02887ee5b6977d6be'), 'average_order_value': 144.11}
# {'_id': ObjectId('617463a9382e631d36774822'), 'average_order_value': 144.0}
# {'_id': ObjectId('620c34622b3da8b6a9d38e3a'), 'average_order_value': 143.84}
# {'_id': ObjectId('63e16c230de38a51f09a75f6'), 'average_order_value': 143.78}
# {'_id': ObjectId('62713169c7abd4f6de644eda'), 'average_order_value': 143.665}
# {'_id': ObjectId('65cd0d6d382f389936a1d3d2'), 'average_order_value': 143.35}
# {'_id': ObjectId('619d01fc24c69a72ee771f3a'), 'average_order_value': 143.18}
# {'_id': ObjectId('6441bc82c828a50348570da2'), 'average_order_value': 143.14}
# {'_id': ObjectId('6015f5e9f69902c5070fb9b1'), 'average_order_value': 143.087775}
# {'_id': ObjectId('65a599416225e60c64186139'), 'average_order_value': 142.91}
# {'_id': ObjectId('6372d5a94e0e14cf7c56bbd7'), 'average_order_value': 142.54}
# {'_id': ObjectId('66f884b79691336968ef3de6'), 'average_order_value': 142.38}
# {'_id': ObjectId('62b4f106a7d7d43b23060c8f'), 'average_order_value': 142.2}
# {'_id': ObjectId('65b6c626479e302978211a7e'), 'average_order_value': 142.07}
# {'_id': ObjectId('608f0f66865a50161ca614aa'), 'average_order_value': 142.02}
# {'_id': ObjectId('610ea5a8bd4311f86491d740'), 'average_order_value': 141.88714285714286}
# {'_id': ObjectId('620fd82db93c4f089170b297'), 'average_order_value': 141.71}
# {'_id': ObjectId('65beb865382f38a88397b2ff'), 'average_order_value': 141.62}
# {'_id': ObjectId('603f97c13ef8276e4e5820c0'), 'average_order_value': 141.47525}
# {'_id': ObjectId('6441f5dbc828a545de574669'), 'average_order_value': 141.42}
# {'_id': ObjectId('65ce3f40382f385777a2f142'), 'average_order_value': 141.31}
# {'_id': ObjectId('640bb9490c1fa3385d4b5cc6'), 'average_order_value': 141.07}
# {'_id': ObjectId('5fea57195f82822b9207caf7'), 'average_order_value': 141.06}
# {'_id': ObjectId('61f934c421a9686debe1886c'), 'average_order_value': 141.03}
# {'_id': ObjectId('63093853a7d7d4b44f3d8af0'), 'average_order_value': 141.0}
# {'_id': ObjectId('63c7085c415cbfa2cbe7741d'), 'average_order_value': 140.98000000000002}
# {'_id': ObjectId('670c2552a81cf2d1c43a8e20'), 'average_order_value': 140.72}
# {'_id': ObjectId('6111d608bd4311820391e9f2'), 'average_order_value': 140.71}
# {'_id': ObjectId('6042ca7e13b4c369e07592e4'), 'average_order_value': 140.6}
# {'_id': ObjectId('64553566d1bf73b2a47175a3'), 'average_order_value': 140.53666666666666}
# {'_id': ObjectId('61ae84b08dfef8ebbefdd14c'), 'average_order_value': 140.49473684210525}
# {'_id': ObjectId('622b8c2ee36092031bc982d5'), 'average_order_value': 140.3}
# {'_id': ObjectId('645a8a3fd1bf73a1cb7589ce'), 'average_order_value': 140.23}
# {'_id': ObjectId('608c2c0f865a508885a5fdcd'), 'average_order_value': 140.13}
# {'_id': ObjectId('66fefc7b48bb4e4084c5bcff'), 'average_order_value': 139.91}
# {'_id': ObjectId('63b9f507415cbf689be735e9'), 'average_order_value': 139.845}
# {'_id': ObjectId('6292a7f6dcd9755c5a95b0b0'), 'average_order_value': 139.8}
# {'_id': ObjectId('6320a0d6a7d7d406244ce9f2'), 'average_order_value': 139.56}
# {'_id': ObjectId('627284c6c7abd4354c651aeb'), 'average_order_value': 139.53}
# {'_id': ObjectId('60fc69512691f278ae2fdb99'), 'average_order_value': 139.23}
# {'_id': ObjectId('605677111427b217e7068c31'), 'average_order_value': 139.22}
# {'_id': ObjectId('6051319b13b4c3490c7654b9'), 'average_order_value': 139.11}
# {'_id': ObjectId('64cfc34ce2bd6e04c750d22c'), 'average_order_value': 139.0}
# {'_id': ObjectId('630a978ea7d7d439c53e6381'), 'average_order_value': 138.94}
# {'_id': ObjectId('5fcc062a54c170d05fd5a17a'), 'average_order_value': 138.83933749999997}
# {'_id': ObjectId('63a4e933415cbfa7dce64bfe'), 'average_order_value': 138.73}
# {'_id': ObjectId('639e5cdff82eb7c2c2a0560b'), 'average_order_value': 138.55}
# {'_id': ObjectId('61e19d5521a9689f58d5dec4'), 'average_order_value': 138.32}
# {'_id': ObjectId('6571f11625523d87189394f3'), 'average_order_value': 138.14}
# {'_id': ObjectId('6726a830a81cf2ec5b56295d'), 'average_order_value': 138.06}
# {'_id': ObjectId('622a6dc8e36092a5eec8bacf'), 'average_order_value': 138.055}
# {'_id': ObjectId('601c7c91f69902ebf01016f2'), 'average_order_value': 137.92796875}
# {'_id': ObjectId('67246afca81cf2c523533716'), 'average_order_value': 137.33}
# {'_id': ObjectId('667dd9ea230c241e6870ce17'), 'average_order_value': 137.28}
# {'_id': ObjectId('610c7594bd4311022291c9e1'), 'average_order_value': 137.18}
# {'_id': ObjectId('63b0a4a5415cbf7c52e7017b'), 'average_order_value': 137.11}
# {'_id': ObjectId('6234b1d4bd3f121c358426ba'), 'average_order_value': 137.09}
# {'_id': ObjectId('64025dca0de38a15199b3dc6'), 'average_order_value': 136.74}
# {'_id': ObjectId('6268741cc7abd4242b5eb97e'), 'average_order_value': 136.615}
# {'_id': ObjectId('6362e67b4e0e14f2f5565d47'), 'average_order_value': 136.38}
# {'_id': ObjectId('6340598faf0c662fb8983451'), 'average_order_value': 136.35000000000002}
# {'_id': ObjectId('64c3d805e2bd6e6eae484546'), 'average_order_value': 136.35}
# {'_id': ObjectId('656b858e25523d4c928fd326'), 'average_order_value': 136.35}
# {'_id': ObjectId('60060eb4f6990227560e8d25'), 'average_order_value': 136.33535074626866}
# {'_id': ObjectId('62fe5e46a7d7d414dc371ef6'), 'average_order_value': 135.99}
# {'_id': ObjectId('611302d8bd431162a691efa8'), 'average_order_value': 135.915}
# {'_id': ObjectId('63af7ca6415cbfe42ce6ffb1'), 'average_order_value': 135.85}
# {'_id': ObjectId('618ef4e09e5c7b47dac37eca'), 'average_order_value': 135.85}
# {'_id': ObjectId('6444554fc828a53aa859ca64'), 'average_order_value': 135.85}
# {'_id': ObjectId('63e6667a0de38a56669a9381'), 'average_order_value': 135.62}
# {'_id': ObjectId('617b1685382e63888c78f39d'), 'average_order_value': 135.3}
# {'_id': ObjectId('604b916013b4c38947761fb9'), 'average_order_value': 135.22312499999998}
# {'_id': ObjectId('62e6cdb0a7d7d4328e275776'), 'average_order_value': 135.14}
# {'_id': ObjectId('61859fff9e5c7b0e67c0bf13'), 'average_order_value': 135.14}
# {'_id': ObjectId('6030371463b7e5321df2a4e1'), 'average_order_value': 134.99}
# {'_id': ObjectId('6341f3afaf0c66321b995d3c'), 'average_order_value': 134.94}
# {'_id': ObjectId('6419a59ba7f10a8012ff3bff'), 'average_order_value': 134.92}
# {'_id': ObjectId('6248c680bd3f12f902913f3f'), 'average_order_value': 134.8}
# {'_id': ObjectId('62cb0bc3a7d7d49a2f15439e'), 'average_order_value': 134.45}
# {'_id': ObjectId('62d31c1fa7d7d41f981af46f'), 'average_order_value': 134.22}
# {'_id': ObjectId('636be0fc4e0e140312568aa3'), 'average_order_value': 134.17}
# {'_id': ObjectId('608f123d865a50730aa614e5'), 'average_order_value': 134.02}
# {'_id': ObjectId('66b3dfbd4b07a90ae9eec18c'), 'average_order_value': 133.95}
# {'_id': ObjectId('6057c38e1427b274c5069676'), 'average_order_value': 133.91}
# {'_id': ObjectId('6680808c230c242fa372ca52'), 'average_order_value': 133.7}
# {'_id': ObjectId('62f5624fa7d7d419713122c2'), 'average_order_value': 133.62}
# {'_id': ObjectId('601f206ef699023b7310481c'), 'average_order_value': 133.24068749999998}
# {'_id': ObjectId('637cfdd2f82eb76abd9f6be7'), 'average_order_value': 132.98}
# {'_id': ObjectId('6302bea6a7d7d43d7439e766'), 'average_order_value': 132.84}
# {'_id': ObjectId('627ec968c7abd4077d6c600f'), 'average_order_value': 132.84}
# {'_id': ObjectId('617abefc382e63f7db78cd5e'), 'average_order_value': 132.78}
# {'_id': ObjectId('626abac5c7abd4171b601a88'), 'average_order_value': 132.56}
# {'_id': ObjectId('60f847c22691f286442fc4b9'), 'average_order_value': 132.55}
# {'_id': ObjectId('618ed6799e5c7b076fc36b27'), 'average_order_value': 132.5}
# {'_id': ObjectId('6712b66ba81cf23988412002'), 'average_order_value': 132.5}
# {'_id': ObjectId('631354d4a7d7d4880443fcd1'), 'average_order_value': 132.17}
# {'_id': ObjectId('6345ec5daf0c6693cb9bf34f'), 'average_order_value': 132.13}
# {'_id': ObjectId('64d9413fe2bd6e37bd57beac'), 'average_order_value': 131.83}
# {'_id': ObjectId('601ece65f699025acc103e0f'), 'average_order_value': 131.748}
# {'_id': ObjectId('6126ae72d7b4487bb99e2687'), 'average_order_value': 131.62}
# {'_id': ObjectId('61015f1b2691f215a03008f9'), 'average_order_value': 131.55}
# {'_id': ObjectId('652ffa14d3476686ec9a8f4f'), 'average_order_value': 131.39}
# {'_id': ObjectId('64fa3185e2bd6ec3456f009e'), 'average_order_value': 131.26}
# {'_id': ObjectId('6414bda12887eef2ec77df60'), 'average_order_value': 131.16}
# {'_id': ObjectId('66f72c8a9691331b50ed5758'), 'average_order_value': 131.02}
# {'_id': ObjectId('5fd2ac2bcda0f7bdd2c175ab'), 'average_order_value': 130.73}
# {'_id': ObjectId('6047a24f13b4c332b575bfb2'), 'average_order_value': 130.58433333333335}
# {'_id': ObjectId('620c275b2b3da89acfd385ae'), 'average_order_value': 130.44833333333335}
# {'_id': ObjectId('620ff08cb93c4fa5af70c405'), 'average_order_value': 130.445}
# {'_id': ObjectId('62eff476a7d7d49f552d8986'), 'average_order_value': 130.33}
# {'_id': ObjectId('63acd459415cbfc21ce6940f'), 'average_order_value': 130.272}
# {'_id': ObjectId('62fd5cd2a7d7d4bed436763e'), 'average_order_value': 130.23}
# {'_id': ObjectId('6238da06bd3f122451870452'), 'average_order_value': 130.19}
# {'_id': ObjectId('5fb93c83e32b2538ea820e37'), 'average_order_value': 130.03}
# {'_id': ObjectId('5fe909efc091c03833d83b93'), 'average_order_value': 130.02}
# {'_id': ObjectId('628819b1dcd97527168f6ebd'), 'average_order_value': 129.98}
# {'_id': ObjectId('621bcc9bb93c4f7d7277741f'), 'average_order_value': 129.75}
# {'_id': ObjectId('62277271e360922a3ec6bce0'), 'average_order_value': 129.68}
# {'_id': ObjectId('60035c4acb2a80db06f0e765'), 'average_order_value': 129.67003749999998}
# {'_id': ObjectId('65787f3e25523d2f3b988fe1'), 'average_order_value': 129.62}
# {'_id': ObjectId('61cb353021a9682773cbdf05'), 'average_order_value': 129.54}
# {'_id': ObjectId('6216acc9b93c4fbea77475df'), 'average_order_value': 129.38}
# {'_id': ObjectId('63766284f82eb797069f4d25'), 'average_order_value': 129.35666666666665}
# {'_id': ObjectId('63acba49415cbfe319e69392'), 'average_order_value': 129.06}
# {'_id': ObjectId('65761a7f25523d570197323a'), 'average_order_value': 128.71}
# {'_id': ObjectId('659eca1e6225e62c5413eef4'), 'average_order_value': 128.59}
# {'_id': ObjectId('61b8c07d21a968c011c41a65'), 'average_order_value': 128.52}
# {'_id': ObjectId('61be648a21a968ae85c6930a'), 'average_order_value': 128.44}
# {'_id': ObjectId('62643ee0c7abd405635c4694'), 'average_order_value': 128.44}
# {'_id': ObjectId('604d2eb013b4c35631763fea'), 'average_order_value': 128.39143750000002}
# {'_id': ObjectId('61ddd28d21a9686fa9d3f7e9'), 'average_order_value': 128.38}
# {'_id': ObjectId('639e09c7f82eb76a72a05039'), 'average_order_value': 128.224}
# {'_id': ObjectId('6661ccbf230c24327d5c4a58'), 'average_order_value': 128.17}
# {'_id': ObjectId('63af6fae415cbf840ce6ff44'), 'average_order_value': 128.17}
# {'_id': ObjectId('65e62c90382f3844cbb84f7d'), 'average_order_value': 128.14}
# {'_id': ObjectId('670b0278a81cf264b2397e55'), 'average_order_value': 128.12}
# {'_id': ObjectId('6521abccd347664f1c9049a1'), 'average_order_value': 128.02}
# {'_id': ObjectId('652c428cd3476670fe982244'), 'average_order_value': 127.96}
# {'_id': ObjectId('62bb4ceda7d7d438270a6943'), 'average_order_value': 127.95}
# {'_id': ObjectId('637e4bd6f82eb7bd269f78bf'), 'average_order_value': 127.95}
# {'_id': ObjectId('6213e1c4b93c4fd901730fad'), 'average_order_value': 127.85}
# {'_id': ObjectId('635db1224e0e149d25564838'), 'average_order_value': 127.85}
# {'_id': ObjectId('67005d8548bb4ea467c7704b'), 'average_order_value': 127.75}
# {'_id': ObjectId('6335db84af0c660823912dab'), 'average_order_value': 127.61666666666667}
# {'_id': ObjectId('626965bec7abd438825f3954'), 'average_order_value': 127.5}
# {'_id': ObjectId('61266c49d7b44825b29e15fa'), 'average_order_value': 127.42333333333333}
# {'_id': ObjectId('669bf112eac02edd2698b776'), 'average_order_value': 127.36}
# {'_id': ObjectId('6089a12d865a5011d2a5d095'), 'average_order_value': 127.31}
# {'_id': ObjectId('5fc96a4d5db8aff342a5b952'), 'average_order_value': 126.5925}
# {'_id': ObjectId('615a288f382e63bebc70d5c1'), 'average_order_value': 126.29}
# {'_id': ObjectId('65c8f520382f3852a99f1a60'), 'average_order_value': 126.18}
# {'_id': ObjectId('61bd232921a9687dcdc5eb68'), 'average_order_value': 126.1475}
# {'_id': ObjectId('6025791f62dd367a34a27802'), 'average_order_value': 126.13599999999998}
# {'_id': ObjectId('60eb5f75640d3c3fe15dcbf0'), 'average_order_value': 126.12}
# {'_id': ObjectId('65343148d347665f699de587'), 'average_order_value': 126.11}
# {'_id': ObjectId('624a1e5bb64018337a01a3b9'), 'average_order_value': 126.09}
# {'_id': ObjectId('65e358ad382f380f46b5eb13'), 'average_order_value': 126.06}
# {'_id': ObjectId('62ab4805a7d7d4a7f1ff13de'), 'average_order_value': 125.92}
# {'_id': ObjectId('67191324a81cf27bcd470800'), 'average_order_value': 125.82}
# {'_id': ObjectId('6054ed431427b2288d067760'), 'average_order_value': 125.52}
# {'_id': ObjectId('61faad482d38563b35ce4cc9'), 'average_order_value': 125.5}
# {'_id': ObjectId('60c79da003b5ac405a325876'), 'average_order_value': 125.49}
# {'_id': ObjectId('62ec24eba7d7d45c652affa8'), 'average_order_value': 125.35}
# {'_id': ObjectId('6538034ad34766fd2da04579'), 'average_order_value': 125.26}
# {'_id': ObjectId('61bbd9ef21a9685e1bc54b56'), 'average_order_value': 125.1}
# {'_id': ObjectId('5fdad5630258b9353b55c04c'), 'average_order_value': 125.07}
# {'_id': ObjectId('65d3e53b382f384397a8e0be'), 'average_order_value': 124.95}
# {'_id': ObjectId('66fd84dd969133badcf3e4ae'), 'average_order_value': 124.944}
# {'_id': ObjectId('63af7e91415cbf849fe6ffcf'), 'average_order_value': 124.91}
# {'_id': ObjectId('61fae8592d38566044ce6f88'), 'average_order_value': 124.82499999999999}
# {'_id': ObjectId('62802c9ec7abd425876d5612'), 'average_order_value': 124.8}
# {'_id': ObjectId('6681c7c3230c245bdb739d08'), 'average_order_value': 124.75}
# {'_id': ObjectId('634c7c81af0c664afca0b4d1'), 'average_order_value': 124.725}
# {'_id': ObjectId('6562859f25523db35689e680'), 'average_order_value': 124.65}
# {'_id': ObjectId('650da107d3476660b6819c9a'), 'average_order_value': 124.63}
# {'_id': ObjectId('622bd156e36092abc1c9c284'), 'average_order_value': 124.55}
# {'_id': ObjectId('63078946a7d7d430003c7c29'), 'average_order_value': 124.41}
# {'_id': ObjectId('63ac8587415cbfb710e69157'), 'average_order_value': 124.22}
# {'_id': ObjectId('646bb105402e7bf05b1718c3'), 'average_order_value': 124.2}
# {'_id': ObjectId('6382a3eff82eb78ad79fc6a9'), 'average_order_value': 124.12}
# {'_id': ObjectId('60ca823b4ebb5c510ca1cf2b'), 'average_order_value': 124.1}
# {'_id': ObjectId('63069cc5a7d7d42e8f3bfe6f'), 'average_order_value': 123.92}
# {'_id': ObjectId('609843ec7bc821f884e84def'), 'average_order_value': 123.9}
# {'_id': ObjectId('62ab923aa7d7d4a8ceff59cb'), 'average_order_value': 123.792}
# {'_id': ObjectId('63a1d0ac0b46f9226ba0085a'), 'average_order_value': 123.78}
# {'_id': ObjectId('62ddadfaa7d7d4e81d218bc8'), 'average_order_value': 123.62666666666667}
# {'_id': ObjectId('63717daa4e0e145c6056b475'), 'average_order_value': 123.55}
# {'_id': ObjectId('62228f6a0d4469be801c4615'), 'average_order_value': 123.5}
# {'_id': ObjectId('610578302691f2769b3011ae'), 'average_order_value': 123.39666666666666}
# {'_id': ObjectId('648c7b60fb19f25c38db3cab'), 'average_order_value': 123.39000000000001}
# {'_id': ObjectId('64765b3c402e7b60961e4657'), 'average_order_value': 123.3}
# {'_id': ObjectId('5ffa0a407dfa5d2f1714ad99'), 'average_order_value': 123.28750000000001}
# {'_id': ObjectId('62e3ec81a7d7d4487a2558f9'), 'average_order_value': 123.05}
# {'_id': ObjectId('60957cf47bc8218ea2e83a28'), 'average_order_value': 122.88428571428572}
# {'_id': ObjectId('6712d72da81cf25228415eca'), 'average_order_value': 122.87}
# {'_id': ObjectId('64089aca0de38a8f6b9b7e41'), 'average_order_value': 122.86}
# {'_id': ObjectId('644bb001d1bf73375a695745'), 'average_order_value': 122.815}
# {'_id': ObjectId('62b75ecea7d7d4640207ba81'), 'average_order_value': 122.79}
# {'_id': ObjectId('64e3e9e7e2bd6e93325fd20c'), 'average_order_value': 122.79}
# {'_id': ObjectId('64021e5d0de38a7c659b3a54'), 'average_order_value': 122.75333333333333}
# {'_id': ObjectId('63f39da60de38a3dd59ae50a'), 'average_order_value': 122.75}
# {'_id': ObjectId('643708d4a7f10a97eefff9f4'), 'average_order_value': 122.63}
# {'_id': ObjectId('5fe92069c091c03a02d83bec'), 'average_order_value': 122.34490625}
# {'_id': ObjectId('61f316d721a9682e7dde758b'), 'average_order_value': 122.27}
# {'_id': ObjectId('665cfc05230c2484bb592526'), 'average_order_value': 122.17}
# {'_id': ObjectId('62d5ca9aa7d7d4b5141c9e07'), 'average_order_value': 122.14}
# {'_id': ObjectId('663fa3d146278d869d391cee'), 'average_order_value': 122.14}
# {'_id': ObjectId('64416fe9c828a5814256ad44'), 'average_order_value': 122.13499999999999}
# {'_id': ObjectId('663ea57b46278d600337e6f2'), 'average_order_value': 122.13}
# {'_id': ObjectId('602c2bca63b7e51ce6f260d0'), 'average_order_value': 122.07478365384615}
# {'_id': ObjectId('62c1cc30a7d7d466cc0ed908'), 'average_order_value': 121.93}
# {'_id': ObjectId('6394e2eef82eb70fcaa02108'), 'average_order_value': 121.92}
# {'_id': ObjectId('6079b1d7ec3ebf1cd0295042'), 'average_order_value': 121.84}
# {'_id': ObjectId('649d8c54e61de40664d98977'), 'average_order_value': 121.83}
# {'_id': ObjectId('622143990d44695f4c1b584c'), 'average_order_value': 121.78}
# {'_id': ObjectId('641df021a7f10a255bff4f6a'), 'average_order_value': 121.72}
# {'_id': ObjectId('65831f2225523d5f27a03275'), 'average_order_value': 121.695}
# {'_id': ObjectId('66f70e6a969133367bed15aa'), 'average_order_value': 121.66}
# {'_id': ObjectId('638a752af82eb77dca9fecc6'), 'average_order_value': 121.49}
# {'_id': ObjectId('661590342d794a0ebd3eb2bd'), 'average_order_value': 121.48}
# {'_id': ObjectId('5fde72183399a758e111f6b0'), 'average_order_value': 121.43091499999998}
# {'_id': ObjectId('601823f9f6990204300fc834'), 'average_order_value': 121.35624999999999}
# {'_id': ObjectId('65c928c4382f380b069f5730'), 'average_order_value': 121.33}
# {'_id': ObjectId('63794301f82eb727b89f5eef'), 'average_order_value': 121.1}
# {'_id': ObjectId('66d9fd6f1c49f83c5bae21ba'), 'average_order_value': 120.98}
# {'_id': ObjectId('6279b79dc7abd49e79696dfc'), 'average_order_value': 120.98}
# {'_id': ObjectId('630a5e52a7d7d4b6253e36b9'), 'average_order_value': 120.85}
# {'_id': ObjectId('617da16c382e637c3979c08c'), 'average_order_value': 120.62}
# {'_id': ObjectId('61cf966521a968b381ce0867'), 'average_order_value': 120.61}
# {'_id': ObjectId('63531924b5c8d0443bacc04f'), 'average_order_value': 120.605}
# {'_id': ObjectId('64adcb47e2bd6e6b9938d656'), 'average_order_value': 120.59}
# {'_id': ObjectId('61ba2f2021a9688510c4ab8b'), 'average_order_value': 120.56}
# {'_id': ObjectId('66f88c40969133261fef4f9b'), 'average_order_value': 120.56}
# {'_id': ObjectId('65107760d3476608f2841334'), 'average_order_value': 120.56}
# {'_id': ObjectId('66ac00d87d30eb6cfdce0460'), 'average_order_value': 120.29}
# {'_id': ObjectId('63c09ec9415cbf1316e74f2d'), 'average_order_value': 120.27}
# {'_id': ObjectId('62af3e62a7d7d47d1f0231af'), 'average_order_value': 120.24}
# {'_id': ObjectId('6248b7c9bd3f12b785912f89'), 'average_order_value': 119.91}
# {'_id': ObjectId('668ea234eac02e5d4e8d35ab'), 'average_order_value': 119.9}
# {'_id': ObjectId('6193c01a9e5c7b431bc4fa84'), 'average_order_value': 119.86}
# {'_id': ObjectId('60132e65f6990269fe0f89fd'), 'average_order_value': 119.77270833333334}
# {'_id': ObjectId('60687c1eec3ebf765928a1af'), 'average_order_value': 119.765}
# {'_id': ObjectId('6496337fe61de44003d4b1ee'), 'average_order_value': 119.625}
# {'_id': ObjectId('60a69bbf51ee2729ef794a17'), 'average_order_value': 119.54}
# {'_id': ObjectId('639be096f82eb7db14a0484c'), 'average_order_value': 119.41}
# {'_id': ObjectId('62acc494a7d7d4f327005ec2'), 'average_order_value': 119.33}
# {'_id': ObjectId('607204bbec3ebfe003291af6'), 'average_order_value': 119.15588235294118}
# {'_id': ObjectId('62e4624fa7d7d4266425c1af'), 'average_order_value': 119.075}
# {'_id': ObjectId('64fbb324d347666a59750bfc'), 'average_order_value': 118.87}
# {'_id': ObjectId('631fbb40a7d7d40dd34c6cfe'), 'average_order_value': 118.85}
# {'_id': ObjectId('621ff2f10d446983351aa626'), 'average_order_value': 118.75}
# {'_id': ObjectId('66f42152819cc81d7d1abda5'), 'average_order_value': 118.705}
# {'_id': ObjectId('60156e1cf69902b5ae0fb00c'), 'average_order_value': 118.64}
# {'_id': ObjectId('607b71deec3ebf648b29605f'), 'average_order_value': 118.63}
# {'_id': ObjectId('62a0b6c4a7d7d411f9f7cd82'), 'average_order_value': 118.56}
# {'_id': ObjectId('60984a407bc821019be84e40'), 'average_order_value': 118.56}
# {'_id': ObjectId('63389189af0c6619ac932475'), 'average_order_value': 118.56}
# {'_id': ObjectId('61b60a658dfef8f30300ec96'), 'average_order_value': 118.43}
# {'_id': ObjectId('5fde6e3e3399a787f211f66a'), 'average_order_value': 118.35156499999998}
# {'_id': ObjectId('666cbae8230c2439c765a4f3'), 'average_order_value': 118.33}
# {'_id': ObjectId('64f3aac1e2bd6e7d766b034b'), 'average_order_value': 118.19999999999999}
# {'_id': ObjectId('622284f60d446938c21c385c'), 'average_order_value': 118.17}
# {'_id': ObjectId('64431ee5c828a53fa7589d8e'), 'average_order_value': 118.1}
# ...
# {'_id': ObjectId('640f78162887ee7c0d77cb1e'), 'average_order_value': 14.14}
# {'_id': ObjectId('6608836e2d794a0e97324ed3'), 'average_order_value': 14.06}
# {'_id': ObjectId('663d3edc46278d72de361633'), 'average_order_value': 14.05}
# {'_id': ObjectId('601c18a0f69902a6a6100edc'), 'average_order_value': 14.04}
# {'_id': ObjectId('63920911f82eb7f996a0106e'), 'average_order_value': 13.97}
# {'_id': ObjectId('657cb1ab25523dece19b9b19'), 'average_order_value': 13.95}
# {'_id': ObjectId('658c3e5feaca183efc261764'), 'average_order_value': 13.95}
# {'_id': ObjectId('62840b8dc7abd47ce66f5446'), 'average_order_value': 13.91}
# {'_id': ObjectId('61fab99e2d38567b72ce55db'), 'average_order_value': 13.89}
# {'_id': ObjectId('61fd5305216a599a6bba7725'), 'average_order_value': 13.87}
# {'_id': ObjectId('64cfd7a2e2bd6e10a250e308'), 'average_order_value': 13.85}
# {'_id': ObjectId('60c2342203b5acb21b32247e'), 'average_order_value': 13.82}
# {'_id': ObjectId('64c68116e2bd6eb54f4a43b3'), 'average_order_value': 13.715}
# {'_id': ObjectId('631b5a3fa7d7d46afc499f1d'), 'average_order_value': 13.634285714285713}
# {'_id': ObjectId('64639843402e7b7fa9106977'), 'average_order_value': 13.625}
# {'_id': ObjectId('647a21d4402e7bdf3a212702'), 'average_order_value': 13.6}
# {'_id': ObjectId('60c9f9a84ebb5c235ea1ca01'), 'average_order_value': 13.6}
# {'_id': ObjectId('6165fbfb382e63435173aa30'), 'average_order_value': 13.59}
# {'_id': ObjectId('62364c6bbd3f1200c98559cd'), 'average_order_value': 13.59}
# {'_id': ObjectId('61ccd70521a968b151ccb309'), 'average_order_value': 13.59}
# {'_id': ObjectId('61dded1021a968582fd4071f'), 'average_order_value': 13.59}
# {'_id': ObjectId('605e006bec3ebf40a1284c1f'), 'average_order_value': 13.59}
# {'_id': ObjectId('610ad678bd4311632b91c499'), 'average_order_value': 13.59}
# {'_id': ObjectId('63d146ff415cbf2a0be7ad2a'), 'average_order_value': 13.59}
# {'_id': ObjectId('5ff89e1b7dfa5d40af148741'), 'average_order_value': 13.584999999999999}
# {'_id': ObjectId('603ad798a246a7ffc408d0ee'), 'average_order_value': 13.584999999999999}
# {'_id': ObjectId('5ff8639a7dfa5db921146f97'), 'average_order_value': 13.584999999999999}
# {'_id': ObjectId('60142c8af69902924a0f9856'), 'average_order_value': 13.572000000000001}
# {'_id': ObjectId('624dd6c8e02d976c85976318'), 'average_order_value': 13.57}
# {'_id': ObjectId('60ca0f994ebb5ce186a1cbc1'), 'average_order_value': 13.57}
# {'_id': ObjectId('644bed86d1bf73b247699c21'), 'average_order_value': 13.57}
# {'_id': ObjectId('60c6650703b5ac2df7323c7d'), 'average_order_value': 13.57}
# {'_id': ObjectId('624b4d42e02d97317695c8b2'), 'average_order_value': 13.57}
# {'_id': ObjectId('64232aeda7f10aa97dff6c2b'), 'average_order_value': 13.57}
# {'_id': ObjectId('60a9873cc4354a023d8c9a24'), 'average_order_value': 13.57}
# {'_id': ObjectId('648b8306fb19f2162ada8460'), 'average_order_value': 13.57}
# {'_id': ObjectId('61420f2e88b11e5171b0950e'), 'average_order_value': 13.57}
# {'_id': ObjectId('6175ad85382e638ecb779e5e'), 'average_order_value': 13.57}
# {'_id': ObjectId('61bcffa321a968095cc5d2bf'), 'average_order_value': 13.57}
# {'_id': ObjectId('66311defa6eb186a0b5a2efc'), 'average_order_value': 13.4}
# {'_id': ObjectId('61be592021a9683ee8c68541'), 'average_order_value': 13.31}
# {'_id': ObjectId('63e52f6f0de38a21439a8df8'), 'average_order_value': 13.17}
# {'_id': ObjectId('631a094ba7d7d41b00489f1d'), 'average_order_value': 13.17}
# {'_id': ObjectId('6463fa62402e7b5d3f10c5f6'), 'average_order_value': 13.17}
# {'_id': ObjectId('66bfb438e59b6913514e1a2c'), 'average_order_value': 13.16}
# {'_id': ObjectId('66b4efc34b07a91be2efe3ec'), 'average_order_value': 13.14}
# {'_id': ObjectId('65b419ef45b19fc4e70ba6aa'), 'average_order_value': 13.13}
# {'_id': ObjectId('5fe25dec37477d697e092e72'), 'average_order_value': 13.11}
# {'_id': ObjectId('66d07fae11e3b40d912dfe76'), 'average_order_value': 13.055}
# {'_id': ObjectId('60b6aa4be00fa9612d19d864'), 'average_order_value': 13.05}
# {'_id': ObjectId('63c0373d415cbf4e46e74d55'), 'average_order_value': 13.01}
# {'_id': ObjectId('62d5d3c8a7d7d440381ca44f'), 'average_order_value': 13.0}
# {'_id': ObjectId('62e84342a7d7d44755284be0'), 'average_order_value': 13.0}
# {'_id': ObjectId('63d841f00de38a0e059a4abc'), 'average_order_value': 12.93}
# {'_id': ObjectId('63e69c230de38a6d6a9a969b'), 'average_order_value': 12.93}
# {'_id': ObjectId('65cd02c9382f38f438a1c72b'), 'average_order_value': 12.93}
# {'_id': ObjectId('6329e686af0c66f71e88d935'), 'average_order_value': 12.89}
# {'_id': ObjectId('61be371f21a9680c1ec67089'), 'average_order_value': 12.81}
# {'_id': ObjectId('652c492ed347663a62982878'), 'average_order_value': 12.805}
# {'_id': ObjectId('619c0e2424c69ab9da76dc2f'), 'average_order_value': 12.75}
# {'_id': ObjectId('64b9584ce2bd6e789440a834'), 'average_order_value': 12.74}
# {'_id': ObjectId('6660a540230c24342c5ba27e'), 'average_order_value': 12.74}
# {'_id': ObjectId('66326562a6eb18ed585b2dc3'), 'average_order_value': 12.74}
# {'_id': ObjectId('65e8bc5e382f389c45b9dc6e'), 'average_order_value': 12.67}
# {'_id': ObjectId('6480b0d0402e7b528225acbd'), 'average_order_value': 12.66}
# {'_id': ObjectId('644c59e2d1bf73dc8e6a5341'), 'average_order_value': 12.66}
# {'_id': ObjectId('6369a4104e0e145c54568085'), 'average_order_value': 12.45}
# {'_id': ObjectId('60142ddcf699027c620f9859'), 'average_order_value': 12.440999999999999}
# {'_id': ObjectId('616c642d382e63b9317526ad'), 'average_order_value': 12.44}
# {'_id': ObjectId('61ff0a10216a592c31bbb2e6'), 'average_order_value': 12.43}
# {'_id': ObjectId('62e9ba0da7d7d4495f293851'), 'average_order_value': 12.43}
# {'_id': ObjectId('6616b1f92d794a7583407567'), 'average_order_value': 12.35}
# {'_id': ObjectId('609ff2924575ff14c2d05e08'), 'average_order_value': 12.35}
# {'_id': ObjectId('65fb36c5c2f334ea77a506ce'), 'average_order_value': 12.27}
# {'_id': ObjectId('6557af1cebde7d276df53623'), 'average_order_value': 12.26}
# {'_id': ObjectId('61ec879521a9683e88db55e8'), 'average_order_value': 12.14}
# {'_id': ObjectId('6274678bc7abd486fc665699'), 'average_order_value': 12.07}
# {'_id': ObjectId('63b47f37415cbfc80de71836'), 'average_order_value': 12.06}
# {'_id': ObjectId('62eaf3eda7d7d4f7572a2103'), 'average_order_value': 12.06}
# {'_id': ObjectId('623b5a9cbd3f1262eb887426'), 'average_order_value': 12.05}
# {'_id': ObjectId('649315ed9d042c6f0e0c0372'), 'average_order_value': 12.04}
# {'_id': ObjectId('61d6123821a968cd4bd0cf6c'), 'average_order_value': 12.03}
# {'_id': ObjectId('65ff523bc2f3341977aa34fb'), 'average_order_value': 11.96}
# {'_id': ObjectId('62e2b8a8a7d7d41fba248386'), 'average_order_value': 11.947999999999999}
# {'_id': ObjectId('6522eba5d34766190d914edc'), 'average_order_value': 11.94}
# {'_id': ObjectId('64be9e65e2bd6e674b4473d8'), 'average_order_value': 11.82}
# {'_id': ObjectId('60ca57b54ebb5c2942a1cc84'), 'average_order_value': 11.8}
# {'_id': ObjectId('65e0ccdf382f384740b39a69'), 'average_order_value': 11.76}
# {'_id': ObjectId('65b2943345b19fcb610a53d1'), 'average_order_value': 11.76}
# {'_id': ObjectId('66106b5c2d794abe2739ea32'), 'average_order_value': 11.7}
# {'_id': ObjectId('65bd2eaf382f38b9ac96492f'), 'average_order_value': 11.67}
# {'_id': ObjectId('64494325762cce353b1f277d'), 'average_order_value': 11.59}
# {'_id': ObjectId('6449459f762cceba1a1f2c47'), 'average_order_value': 11.59}
# {'_id': ObjectId('618d78dd9e5c7b8327c2e718'), 'average_order_value': 11.58}
# {'_id': ObjectId('63928393f82eb72091a01383'), 'average_order_value': 11.57}
# {'_id': ObjectId('61d5d5fb21a968789ad0b5a1'), 'average_order_value': 11.41}
# {'_id': ObjectId('6702c13148bb4e645dca2a81'), 'average_order_value': 11.32}
# {'_id': ObjectId('617ac335382e633ce078d30e'), 'average_order_value': 11.318333333333333}
# {'_id': ObjectId('615de88e382e6367ed71de1c'), 'average_order_value': 11.11}
# {'_id': ObjectId('613f879188b11e109fb00581'), 'average_order_value': 11.11}
# {'_id': ObjectId('62bce359a7d7d41dfb0b80fb'), 'average_order_value': 11.11}
# {'_id': ObjectId('60fc33872691f2c66f2fdb3c'), 'average_order_value': 11.11}
# {'_id': ObjectId('6117d42848521b089be7cfa4'), 'average_order_value': 11.08}
# {'_id': ObjectId('64e00585e2bd6e46d05cefc2'), 'average_order_value': 10.78}
# {'_id': ObjectId('64dfadbce2bd6e4c085c7a2a'), 'average_order_value': 10.77}
# {'_id': ObjectId('653a87e3d347663f18a20d42'), 'average_order_value': 10.77}
# {'_id': ObjectId('62be2e61a7d7d4d74d0c637e'), 'average_order_value': 10.74}
# {'_id': ObjectId('62d5be16a7d7d4b01a1c95a1'), 'average_order_value': 10.73}
# {'_id': ObjectId('61b609b88dfef80e1300ec2d'), 'average_order_value': 10.72}
# {'_id': ObjectId('60e4b472640d3ccccc5d5079'), 'average_order_value': 10.69}
# {'_id': ObjectId('60ca61164ebb5c35cfa1ccb3'), 'average_order_value': 10.594999999999999}
# {'_id': ObjectId('632b6ee0af0c66177689ffe9'), 'average_order_value': 10.55}
# {'_id': ObjectId('60ce607c4ebb5ceaaba1f13b'), 'average_order_value': 10.51}
# {'_id': ObjectId('6584d4e8eaca1874ef21eb5a'), 'average_order_value': 10.45}
# {'_id': ObjectId('65678ddd25523d212b8c9cdd'), 'average_order_value': 10.45}
# {'_id': ObjectId('649f00c7e2bd6ebe1a2f9f82'), 'average_order_value': 10.44}
# {'_id': ObjectId('63926390f82eb70726a012ae'), 'average_order_value': 10.38}
# {'_id': ObjectId('610567b32691f24195301190'), 'average_order_value': 10.21}
# {'_id': ObjectId('62b47061a7d7d47f69058cf0'), 'average_order_value': 10.18}
# {'_id': ObjectId('65b6bb11479e30f13221099e'), 'average_order_value': 10.18}
# {'_id': ObjectId('66da19ee1c49f850f0ae5417'), 'average_order_value': 10.18}
# {'_id': ObjectId('61476d76382e6348286bfdfc'), 'average_order_value': 10.18}
# {'_id': ObjectId('616226c1382e63281e72c4d5'), 'average_order_value': 10.17}
# {'_id': ObjectId('668eaf91eac02ed8138d634b'), 'average_order_value': 10.11}
# {'_id': ObjectId('6596e374eaca181e422d858c'), 'average_order_value': 9.92}
# {'_id': ObjectId('60a3d4af4575ff0de1d06986'), 'average_order_value': 9.88}
# {'_id': ObjectId('637565f6f82eb74dd79f47b0'), 'average_order_value': 9.88}
# {'_id': ObjectId('61101237bd43110bfe91e02c'), 'average_order_value': 9.74}
# {'_id': ObjectId('64b83700e2bd6e7ed53fc461'), 'average_order_value': 9.57}
# {'_id': ObjectId('66feb89c96913304caf5325d'), 'average_order_value': 9.56}
# {'_id': ObjectId('655250ffebde7dc49bf1adaa'), 'average_order_value': 9.52}
# {'_id': ObjectId('658cb196eaca18e3e2267a10'), 'average_order_value': 9.5}
# {'_id': ObjectId('6383c7d8f82eb73b159fcaf4'), 'average_order_value': 9.25}
# {'_id': ObjectId('619cf87f24c69a18af771cac'), 'average_order_value': 9.19}
# {'_id': ObjectId('61e3508a21a9687dedd6e93e'), 'average_order_value': 9.18}
# {'_id': ObjectId('652ae662d3476638a8970554'), 'average_order_value': 9.14}
# {'_id': ObjectId('638e31f2f82eb72fb99ffd22'), 'average_order_value': 9.11}
# {'_id': ObjectId('644d30e9d1bf731b786b065b'), 'average_order_value': 9.05}
# {'_id': ObjectId('60df84c4640d3c30fa5d387b'), 'average_order_value': 8.81}
# {'_id': ObjectId('62dc327ca7d7d4bf3620ccfa'), 'average_order_value': 8.775}
# {'_id': ObjectId('6604b9ae2d794a4aa52d9a29'), 'average_order_value': 8.68}
# {'_id': ObjectId('60ca61e14ebb5c9bb5a1ccbf'), 'average_order_value': 8.66}
# {'_id': ObjectId('61e05fcb21a968f20dd53729'), 'average_order_value': 8.62}
# {'_id': ObjectId('662311f33d9bc5670a004065'), 'average_order_value': 8.51}
# {'_id': ObjectId('65da45c8382f38a1cbadee98'), 'average_order_value': 8.5}
# {'_id': ObjectId('601e3787f69902fcf2103a07'), 'average_order_value': 8.39}
# {'_id': ObjectId('6552ba63ebde7d5c6ef20620'), 'average_order_value': 8.37}
# {'_id': ObjectId('60d4908c640d3cb9545cc24a'), 'average_order_value': 8.325}
# {'_id': ObjectId('616623e8382e63418873b42f'), 'average_order_value': 8.18}
# {'_id': ObjectId('663e80e446278d835c3787e9'), 'average_order_value': 8.17}
# {'_id': ObjectId('65ce8934382f38e6b6a38626'), 'average_order_value': 8.17}
# {'_id': ObjectId('632a0e8eaf0c661f4e88f56b'), 'average_order_value': 8.1412}
# {'_id': ObjectId('60f3382a2691f25cc32f8afa'), 'average_order_value': 8.05}
# {'_id': ObjectId('618841899e5c7bfad9c181f0'), 'average_order_value': 8.004285714285714}
# {'_id': ObjectId('6133ee9088b11e6af3ad243d'), 'average_order_value': 7.91}
# {'_id': ObjectId('60cbd90c4ebb5ca947a1db9c'), 'average_order_value': 7.88}
# {'_id': ObjectId('64134d6f2887ee5d1877d7f8'), 'average_order_value': 7.875}
# {'_id': ObjectId('6511b9b2d34766c1a084f35d'), 'average_order_value': 7.84}
# {'_id': ObjectId('64b9cacde2bd6ea23e41376b'), 'average_order_value': 7.84}
# {'_id': ObjectId('65de2a7b382f381170b1004e'), 'average_order_value': 7.84}
# {'_id': ObjectId('6097269c7bc821087be84622'), 'average_order_value': 7.72}
# {'_id': ObjectId('60aff41ce00fa959cc19b104'), 'average_order_value': 7.6425}
# {'_id': ObjectId('659ee5386225e6df04140e3b'), 'average_order_value': 7.48}
# {'_id': ObjectId('61bb661321a9682da7c50fdf'), 'average_order_value': 7.41}
# {'_id': ObjectId('608ed51e865a501768a6132c'), 'average_order_value': 7.41}
# {'_id': ObjectId('6060c93eec3ebf44e72867a6'), 'average_order_value': 7.41}
# {'_id': ObjectId('6250535ae02d97c6c299236d'), 'average_order_value': 7.41}
# {'_id': ObjectId('605de388ec3ebf3924284af9'), 'average_order_value': 7.41}
# {'_id': ObjectId('619189bd9e5c7bb3c1c44c02'), 'average_order_value': 7.4}
# {'_id': ObjectId('669a920aeac02edf4f97479d'), 'average_order_value': 7.18}
# {'_id': ObjectId('61995b2e24c69aa03d758cc6'), 'average_order_value': 6.91}
# {'_id': ObjectId('60cfb6c94ebb5c7e7fa20092'), 'average_order_value': 6.77}
# {'_id': ObjectId('6573925f25523d3a79950d7e'), 'average_order_value': 6.59}
# {'_id': ObjectId('6585e63eeaca18025222ba9d'), 'average_order_value': 6.53}
# {'_id': ObjectId('65130430d347664cea85e8dc'), 'average_order_value': 6.52}
# {'_id': ObjectId('616dc860382e63305e75774b'), 'average_order_value': 6.52}
# {'_id': ObjectId('6292a981dcd975705195b27e'), 'average_order_value': 6.5}
# {'_id': ObjectId('613e194788b11e77a2afb087'), 'average_order_value': 6.495}
# {'_id': ObjectId('60a059564575ff6064d0641b'), 'average_order_value': 6.22}
# {'_id': ObjectId('6176de5e382e6363fd77ecd7'), 'average_order_value': 6.21}
# {'_id': ObjectId('634aa77aaf0c6661419f59c5'), 'average_order_value': 6.18}
# {'_id': ObjectId('618059585f4169467a15a67b'), 'average_order_value': 6.011333333333334}
# {'_id': ObjectId('61328f624867e9d3ad17d72a'), 'average_order_value': 5.94}
# {'_id': ObjectId('617f10dd382e6385417a20e5'), 'average_order_value': 5.816190476190476}
# {'_id': ObjectId('61b0d19a8dfef87e26fe9fce'), 'average_order_value': 5.62}
# {'_id': ObjectId('60c96e8d03b5ac4fcd325ff8'), 'average_order_value': 5.1775}
# {'_id': ObjectId('60cbef0b4ebb5c2b62a1dbbb'), 'average_order_value': 5.095}
# {'_id': ObjectId('6182907ce5993647e1b88f0e'), 'average_order_value': 5.05}
# {'_id': ObjectId('60ea1484640d3c72195d9de8'), 'average_order_value': 4.75}
# {'_id': ObjectId('60e706da640d3cee465d69cc'), 'average_order_value': 3.71}
# {'_id': ObjectId('60df7f70640d3ce1de5d3856'), 'average_order_value': 1.6460000000000001}
# {'_id': ObjectId('6095bb437bc8217899e83cb5'), 'average_order_value': 0.9}
# {'_id': ObjectId('60e4741d640d3c148d5d4ebe'), 'average_order_value': 0.64}
# {'_id': ObjectId('6509d76fd3476607497f0aca'), 'average_order_value': 0.0}
# {'_id': ObjectId('64615bf8402e7b199f0f413e'), 'average_order_value': 0.0}
# {'_id': ObjectId('63953168f82eb7026ba024cf'), 'average_order_value': 0.0}
# {'_id': ObjectId('60c261e103b5ac81f43227fd'), 'average_order_value': 0.0}
# {'_id': ObjectId('658c7084eaca189176263e48'), 'average_order_value': 0.0}
# {'_id': ObjectId('60ccc3bc4ebb5c6feba1e3c7'), 'average_order_value': 0.0}
# {'_id': ObjectId('64fe2a57d347660c787718e8'), 'average_order_value': 0.0}
# {'_id': ObjectId('6726be95a81cf2c60b5651bb'), 'average_order_value': 0.0}
# {'_id': ObjectId('615ddfe7382e63ca4c71dae2'), 'average_order_value': 0.0}
# {'_id': ObjectId('60fc64072691f2f2232fdb8a'), 'average_order_value': 0.0}
# {'_id': ObjectId('634c131baf0c666d31a06356'), 'average_order_value': 0.0}
# {'_id': ObjectId('60eb37b9640d3ce09c5da219'), 'average_order_value': 0.0}
# {'_id': ObjectId('64372cb5a7f10ad6abfffa1d'), 'average_order_value': 0.0}
# {'_id': ObjectId('60ca168c4ebb5c4dc4a1cbd0'), 'average_order_value': 0.0}
# {'_id': ObjectId('61cf79b421a9688f32cdf57b'), 'average_order_value': 0.0}
# {'_id': ObjectId('61327e2c4867e9d99517bedf'), 'average_order_value': None}

# %% [markdown]
# # year over growth restaurant wise

# %%
# Not sure about this
pipeline = [
    {
        "$match": {
            "createdAt": {"$gte": datetime.datetime(2020, 1, 1)}  # Starting from 2020 
        }
    },
    {
        "$group": {
            "_id": {
                "year": {"$year": "$createdAt"},
                "store_id": "$store_id"
            },
            "total_orders": {"$sum": 1}
        }
    },
    {
        "$lookup": {
            "from": "stores",
            "localField": "_id.store_id",
            "foreignField": "_id",
            "as": "store_details"
        }
    },
    {
        "$unwind": "$store_details"
    },
    {
        "$sort": {"_id.year": 1, "store_details.name": 1}
    },
    {
        "$group": {
            "_id": "$store_details.name",
            "orders_per_year": {
                "$push": {
                    "year": "$_id.year",
                    "orders": "$total_orders"
                }
            }
        }
    },
    {
        "$project": {
            "store_name": "$_id",
            "year_over_year_growth": {
                "$map": {
                    "input": {"$range": [0, {"$subtract": [{"$size": "$orders_per_year"}, 1]}]},
                    "as": "idx",
                    "in": {
                        "year": {"$arrayElemAt": ["$orders_per_year.year", {"$add": ["$$idx", 1]}]},
                        "growth": {
                            "$subtract": [
                                {"$divide": [
                                    {"$subtract": [
                                        {"$arrayElemAt": ["$orders_per_year.orders", {"$add": ["$$idx", 1]}]},
                                        {"$arrayElemAt": ["$orders_per_year.orders", "$$idx"]}
                                    ]},
                                    {"$arrayElemAt": ["$orders_per_year.orders", "$$idx"]}
                                ]},
                                1
                            ]
                        }
                    }
                }
            }
        }
    }
]

results = db.orders.aggregate(pipeline)
results_list = list(results)  # Convert cursor to list

# Print results as JSON
print(json.dumps(results_list, indent=2, default=str))  # Use default=str to handle datetime objects
# Out:
# [
#   {
#     "_id": "Hombre Y Lobo",
#     "store_name": "Hombre Y Lobo",
#     "year_over_year_growth": [
#       {
#         "year": 2022,
#         "growth": 4.333333333333333
#       },
#       {
#         "year": 2023,
#         "growth": -1.5
#       },
#       {
#         "year": 2024,
#         "growth": -1.526315789473684
#       }
#     ]
#   },
#   {
#     "_id": "La Verdad",
#     "store_name": "La Verdad",
#     "year_over_year_growth": [
#       {
#         "year": 2024,
#         "growth": 10.0
#       }
#     ]
#   },
#   {
#     "_id": "Phyu Thein",
#     "store_name": "Phyu Thein",
#     "year_over_year_growth": []
#   },
#   {
#     "_id": "Malkia and Co.",
#     "store_name": "Malkia and Co.",
#     "year_over_year_growth": []
#   },
#   {
#     "_id": "Cafe 59",
#     "store_name": "Cafe 59",
#     "year_over_year_growth": [
#       {
#         "year": 2021,
#         "growth": 9.48
#       },
#       {
#         "year": 2022,
#         "growth": -1.0116144018583042
#       },
#       {
#         "year": 2023,
#         "growth": -1.2679200940070505
#       },
#       {
#         "year": 2024,
#         "growth": -1.261637239165329
#       }
#     ]
#   },
#   {
#     "_id": "Cristos Wood Fired Pizza & Pasta",
#     "store_name": "Cristos Wood Fired Pizza & Pasta",
#     "year_over_year_growth": []
#   },
#   {
#     "_id": "Brierwood Wine & Spirits",
#     "store_name": "Brierwood Wine & Spirits",
#     "year_over_year_growth": [
#       {
#         "year": 2022,
#         "growth": -0.38095238095238093
#       }
#     ]
#   },
#   {
#     "_id": "Lakeshore Cafe",
#     "store_name": "Lakeshore Cafe",
#     "year_over_year_growth": [
#       {
#         "year": 2022,
#         "growth": -0.12096774193548387
#       },
#       {
#         "year": 2023,
#         "growth": -0.7124463519313304
#       },
#       {
#         "year": 2024,
#         "growth": -1.1966666666666668
#       }
#     ]
#   },
#   {
#     "_id": "Fat Bob's Smokehouse",
#     "store_name": "Fat Bob's Smokehouse",
#     "year_over_year_growth": [
#       {
#         "year": 2021,
#         "growth": 9.022222222222222
#       },
#       {
#         "year": 2022,
#         "growth": -0.9092741935483871
#       },
#       {
#         "year": 2023,
#         "growth": -1.5110905730129391
#       },
#       {
#         "year": 2024,
#         "growth": -1.4272211720226844
#       }
#     ]
#   },
#   {
#     "_id": "William's Kitchen",
#     "store_name": "William's Kitchen",
#     "year_over_year_growth": []
#   },
#   {
#     "_id": "Pizza Plant Transit",
#     "store_name": "Pizza Plant Transit",
#     "year_over_year_growth": [
#       {
#         "year": 2022,
#         "growth": 3.5194805194805197
#       },
#       {
#         "year": 2023,
#         "growth": -1.5082352941176471
#       },
#       {
#         "year": 2024,
#         "growth": -1.569377990430622
#       }
#     ]
#   },
#   {
#     "_id": "Grass Fed Vegan Butcher Shop",
#     "store_name": "Grass Fed Vegan Butcher Shop",
#     "year_over_year_growth": [
#       {
#         "year": 2024,
#         "growth": -0.7563451776649746
#       }
#     ]
#   },
#   {
#     "_id": "Giacobbi's Cucina Citta",
#     "store_name": "Giacobbi's Cucina Citta",
#     "year_over_year_growth": [
#       {
#         "year": 2023,
#         "growth": 12.0
#       },
#       {
#         "year": 2024,
#         "growth": -1.4107142857142856
#       }
#     ]
#   },
#   {
#     "_id": "Off The Wall Sandwich Company",
#     "store_name": "Off The Wall Sandwich Company",
#     "year_over_year_growth": [
#       {
#         "year": 2021,
#         "growth": 29.573529411764707
#       },
#       {
#         "year": 2022,
#         "growth": -1.096413600372613
#       },
#       {
#         "year": 2023,
#         "growth": -1.577319587628866
#       },
#       {
#         "year": 2024,
#         "growth": -1.697560975609756
#       }
#     ]
#   },
#   {
#     "_id": "Colter Bay",
#     "store_name": "Colter Bay",
#     "year_over_year_growth": [
#       {
#         "year": 2021,
#         "growth": 4.0
#       },
#       {
#         "year": 2022,
#         "growth": -0.40909090909090906
#       },
#       {
#         "year": 2023,
#         "growth": -1.4
#       },
#       {
#         "year": 2024,
#         "growth": -1.7142857142857144
#       }
#     ]
#   },
#   {
#     "_id": "The Ridge West Seneca",
#     "store_name": "The Ridge West Seneca",
#     "year_over_year_growth": []
#   },
#   {
#     "_id": "The Grange Outpost",
#     "store_name": "The Grange Outpost",
#     "year_over_year_growth": [
#       {
#         "year": 2023,
#         "growth": 2.75
#       },
#       {
#         "year": 2024,
#         "growth": -1.3567251461988303
#       }
#     ]
#   },
#   {
#     "_id": "Voula's Greek Sweets",
#     "store_name": "Voula's Greek Sweets",
#     "year_over_year_growth": [
#       {
#         "year": 2023,
#         "growth": -0.8246153846153846
#       },
#       {
#         "year": 2024,
#         "growth": -1.3821989528795813
#       }
#     ]
#   },
#   {
#     "_id": "Two Nines Kitchen & Bar",
#     "store_name": "Two Nines Kitchen & Bar",
#     "year_over_year_growth": []
#   },
#   {
#     "_id": "Winfield's Pub",
#     "store_name": "Winfield's Pub",
#     "year_over_year_growth": [
#       {
#         "year": 2024,
#         "growth": -0.5483870967741935
#       }
#     ]
#   },
#   {
#     "_id": "Milk & Tea",
#     "store_name": "Milk & Tea",
#     "year_over_year_growth": [
#       {
#         "year": 2023,
#         "growth": 0.4444444444444444
#       },
#       {
#         "year": 2024,
#         "growth": -1.1590909090909092
#       }
#     ]
#   },
#   {
#     "_id": "O'Brien's West End",
#     "store_name": "O'Brien's West End",
#     "year_over_year_growth": []
#   },
#   {
#     "_id": "Ballyhoo",
#     "store_name": "Ballyhoo",
#     "year_over_year_growth": [
#       {
#         "year": 2021,
#         "growth": 6.017543859649122
#       },
#       {
#         "year": 2022,
#         "growth": -1.1531728665207877
#       },
#       {
#         "year": 2023,
#         "growth": -1.297157622739018
#       },
#       {
#         "year": 2024,
#         "growth": -1.2794117647058822
#       }
#     ]
#   },
#   {
#     "_id": "Sports City Pizza Pub",
#     "store_name": "Sports City Pizza Pub",
#     "year_over_year_growth": [
#       {
#         "year": 2022,
#         "growth": 5.9907407407407405
#       },
#       {
#         "year": 2023,
#         "growth": -1.0683661645422944
#       },
#       {
#         "year": 2024,
#         "growth": -1.6629353233830846
#       }
#     ]
#   },
#   {
#     "_id": "Old Orchard Inn",
#     "store_name": "Old Orchard Inn",
#     "year_over_year_growth": [
#       {
#         "year": 2024,
#         "growth": -1.0
#       }
#     ]
#   },
#   {
#     "_id": "Lime House Sushi & Ramen | Hamburg",
#     "store_name": "Lime House Sushi & Ramen | Hamburg",
#     "year_over_year_growth": [
#       {
#         "year": 2023,
#         "growth": -0.5818181818181818
#       },
#       {
#         "year": 2024,
#         "growth": -1.7264957264957266
#       }
#     ]
#   },
#   {
#     "_id": "Rin Thai Bistro",
#     "store_name": "Rin Thai Bistro",
#     "year_over_year_growth": [
#       {
#         "year": 2023,
#         "growth": -0.8434959349593496
#       },
#       {
#         "year": 2024,
#         "growth": -1.757469244288225
#       }
#     ]
#   },
#   {
#     "_id": "Butera's Craft Beer & Craft Pizza",
#     "store_name": "Butera's Craft Beer & Craft Pizza",
#     "year_over_year_growth": [
#       {
#         "year": 2021,
#         "growth": 0.56
#       },
#       {
#         "year": 2022,
#         "growth": -1.234375
#       },
#       {
#         "year": 2023,
#         "growth": -0.9438775510204082
#       },
#       {
#         "year": 2024,
#         "growth": -1.4879227053140096
#       }
#     ]
#   },
#   {
#     "_id": "Pham's Kitchen",
#     "store_name": "Pham's Kitchen",
#     "year_over_year_growth": [
#       {
#         "year": 2024,
#         "growth": 0.6666666666666667
#       }
#     ]
#   },
#   {
#     "_id": "Aguacates Mexican Bar & Grill | Elmwood",
#     "store_name": "Aguacates Mexican Bar & Grill | Elmwood",
#     "year_over_year_growth": [
#       {
#         "year": 2022,
#         "growth": 9.125
#       },
#       {
#         "year": 2023,
#         "growth": -0.0898876404494382
#       },
#       {
#         "year": 2024,
#         "growth": -0.3411764705882353
#       }
#     ]
#   },
#   {
#     "_id": "Glen Park Tavern ",
#     "store_name": "Glen Park Tavern ",
#     "year_over_year_growth": [
#       {
#         "year": 2022,
#         "growth": -1.2808716707021792
#       },
#       {
#         "year": 2023,
#         "growth": -1.239057239057239
#       },
#       {
#         "year": 2024,
#         "growth": -0.8982300884955752
#       }
#     ]
#   },
#   {
#     "_id": "Buffalo Deep Dish",
#     "store_name": "Buffalo Deep Dish",
#     "year_over_year_growth": [
#       {
#         "year": 2024,
#         "growth": 0.8223350253807107
#       }
#     ]
#   },
#   {
#     "_id": "India Gate",
#     "store_name": "India Gate",
#     "year_over_year_growth": [
#       {
#         "year": 2022,
#         "growth": -0.8292682926829268
#       },
#       {
#         "year": 2023,
#         "growth": -1.53125
#       },
#       {
#         "year": 2024,
#         "growth": -1.6222222222222222
#       }
#     ]
#   },
#   {
#     "_id": "Louie's Texas Red Hots - Orchard Park ",
#     "store_name": "Louie's Texas Red Hots - Orchard Park ",
#     "year_over_year_growth": [
#       {
#         "year": 2022,
#         "growth": -1.3269230769230769
#       },
#       {
#         "year": 2023,
#         "growth": -1.2
#       },
#       {
#         "year": 2024,
#         "growth": -0.8095238095238095
#       }
#     ]
#   },
#   {
#     "_id": "Hanzlian's Homemade Sausage",
#     "store_name": "Hanzlian's Homemade Sausage",
#     "year_over_year_growth": [
#       {
#         "year": 2024,
#         "growth": -1.75
#       }
#     ]
#   },
#   {
#     "_id": "Blue Eyed Baker",
#     "store_name": "Blue Eyed Baker",
#     "year_over_year_growth": []
#   },
#   {
#     "_id": "Allentown Pizza",
#     "store_name": "Allentown Pizza",
#     "year_over_year_growth": [
#       {
#         "year": 2021,
#         "growth": 22.4
#       },
#       {
#         "year": 2022,
#         "growth": -1.360655737704918
#       },
#       {
#         "year": 2023,
#         "growth": -1.5128205128205128
#       },
#       {
#         "year": 2024,
#         "growth": -1.4473684210526316
#       }
#     ]
#   },
#   {
#     "_id": "K Dara Noodle Bar",
#     "store_name": "K Dara Noodle Bar",
#     "year_over_year_growth": [
#       {
#         "year": 2023,
#         "growth": 519.0
#       },
#       {
#         "year": 2024,
#         "growth": -1.161228406909789
#       }
#     ]
#   },
#   {
#     "_id": "Undergrounds Coffee House and Roastery ",
#     "store_name": "Undergrounds Coffee House and Roastery ",
#     "year_over_year_growth": [
#       {
#         "year": 2022,
#         "growth": 3.5
#       },
#       {
#         "year": 2023,
#         "growth": -1.5515151515151515
#       },
#       {
#         "year": 2024,
#         "growth": -1.5135135135135136
#       }
#     ]
#   },
#   {
#     "_id": "Chef Bigwayne Jamaican Cuisine",
#     "store_name": "Chef Bigwayne Jamaican Cuisine",
#     "year_over_year_growth": []
#   },
#   {
#     "_id": "Egyptian Bites",
#     "store_name": "Egyptian Bites",
#     "year_over_year_growth": []
#   },
#   {
#     "_id": "VinLouie's",
#     "store_name": "VinLouie's",
#     "year_over_year_growth": [
#       {
#         "year": 2022,
#         "growth": -0.23333333333333328
#       },
#       {
#         "year": 2023,
#         "growth": -0.9433962264150944
#       },
#       {
#         "year": 2024,
#         "growth": -1.8035714285714286
#       }
#     ]
#   },
#   {
#     "_id": "Mister Pizza | Elmwood",
#     "store_name": "Mister Pizza | Elmwood",
#     "year_over_year_growth": []
#   },
#   {
#     "_id": "Oralia",
#     "store_name": "Oralia",
#     "year_over_year_growth": []
#   },
#   {
#     "_id": "Marco\u2019s Italian Restaurant ",
#     "store_name": "Marco\u2019s Italian Restaurant ",
#     "year_over_year_growth": [
#       {
#         "year": 2022,
#         "growth": -0.30434782608695654
#       },
#       {
#         "year": 2023,
#         "growth": -1.3846153846153846
#       },
#       {
#         "year": 2024,
#         "growth": -1.125
#       }
#     ]
#   },
#   {
#     "_id": "Mario's Bistro & Brews",
#     "store_name": "Mario's Bistro & Brews",
#     "year_over_year_growth": [
#       {
#         "year": 2024,
#         "growth": 0.0
#       }
#     ]
#   }
# ]
